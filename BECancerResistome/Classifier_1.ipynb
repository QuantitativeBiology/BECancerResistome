# %% [markdown]
# # Classifier 1 - Plasmid vs Control training dataset

# %%
import BECancerResistome
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import math
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, average_precision_score
from sklearn.utils.class_weight import compute_sample_weight
import time
from skopt import BayesSearchCV
from skopt.space import Real, Integer

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load Data

# %%
annotated_control_vs_plasmid_EG = pd.read_csv("data/6_VEP/zscores-unambiguous-VEPannotated-processed-plasmid-vs-control-EG.csv")

# %%
annotated_control_vs_plasmid_EG.head()
# Out:
#                   Guide Editor    Gene Cell_Line Drug    zscore Hit_class  \
# 0  AAAAAACATCGTAGTAGCAG    CBE  RICTOR      A375   DO -0.126512   non-hit
# 1  AAAAAACTCAACAGCAGTGA    CBE    NRAS      A375   DO  0.491844   non-hit
# 2  AAAAAACTGGCCAGGTGAGC    CBE  PIK3CB      A375   DO  0.161287   non-hit
# 3  AAAAAACTGTTTGGGACCTC    CBE    EGFR      A375   DO -0.429684   non-hit
# 4  AAAAAATCCAGCGTCTAAGC    CBE     MYC      A375   DO  0.122982   non-hit
#
#   Target Transcript ID RefSeq match transcript (MANE Select) Amino Acid Edits  \
# 0    ENST00000357387.8                           NM_152756.5       His1109Tyr
# 1    ENST00000369535.5                           NM_002524.5        Leu171Phe
# 2    ENST00000674063.1                           NM_006219.3        Thr930Ile
# 3    ENST00000275493.7                           NM_005228.5        Leu480Leu
# 4    ENST00000621592.8                           NM_002467.6          Asp2Asn
#
#    Mutation_Category_enc  IMPACT_enc  TSL  SIFT_pathogenicity  \
# 0                    3.0         2.0  1.0                 1.0
# 1                    3.0         2.0  1.0                 0.1
# 2                    3.0         2.0  NaN                 0.0
# 3                    2.0         1.0  1.0                 NaN
# 4                    3.0         2.0  1.0                 0.0
#
#    PolyPhen_pathogenicity  REVEL  ClinPred  am_pathogenicity  EVE_SCORE  \
# 0                   0.000  0.214  0.463040            0.0685        NaN
# 1                     NaN  0.141  0.413488            0.1149        NaN
# 2                   0.862    NaN  0.373381            0.7209        NaN
# 3                     NaN    NaN       NaN               NaN        NaN
# 4                   0.199    NaN  0.453567               NaN        NaN
#
#    BayesDel_noAF_score  DANN_score  DEOGEN2_score  ESM1b_score  \
# 0            -0.402171    0.970933       0.045001       -4.388
# 1            -0.222424    0.993713       0.120039       -5.943
# 2            -0.058094    0.998396       0.879846      -10.191
# 3                  NaN         NaN            NaN          NaN
# 4            -0.438067    0.984375            NaN          NaN
#
#    Eigen-PC-phred_coding  Eigen-PC-raw_coding  GERP++_NR  GERP++_RS  \
# 0               5.314964             0.516773       5.75       5.75
# 1               3.683551             0.294249       5.86       5.86
# 2               4.891242             0.469329       5.63       3.78
# 3                    NaN                  NaN        NaN        NaN
# 4               1.792897            -0.197017       4.31       2.43
#
#    LIST-S2_score  MPC_rankscore  MPC_score  MVP_score  MetaRNN_score  \
# 0       0.917608        0.44121   0.445060   0.093490       0.179100
# 1       0.865513        0.74516   1.008632   0.619943       0.190982
# 2            NaN        0.73854        NaN        NaN            NaN
# 3            NaN            NaN        NaN        NaN            NaN
# 4       0.397160            NaN        NaN   0.733174       0.215208
#
#    MetaSVM_score  MutFormer_score  MutationAssessor_score  PROVEAN_score  \
# 0        -1.0259         0.000785                   0.345          -0.22
# 1        -0.9613         0.907693                   1.385          -1.28
# 2         0.6434         0.529280                   3.705            NaN
# 3            NaN              NaN                     NaN            NaN
# 4        -0.7405         0.036037                     NaN            NaN
#
#    PrimateAI_pred_enc  VARITY_R_LOO_score  bStatistic  fathmm-XF_coding_score  \
# 0                 1.0            0.094767       226.0                0.800526
# 1                 1.0            0.072730       819.0                0.580949
# 2                 0.0            0.365695       856.0                0.310513
# 3                 NaN                 NaN         NaN                     NaN
# 4                 1.0                 NaN       951.0                0.226082
#
#    gMVP_score  phastCons100way_vertebrate  phyloP100way_vertebrate  \
# 0         NaN                       1.000                    5.938
# 1    0.628916                       1.000                    4.055
# 2         NaN                       0.998                    2.094
# 3         NaN                         NaN                      NaN
# 4    0.128201                       1.000                    1.507
#
#    CADD_PHRED  MaxEntScan_alt  MaxEntScan_diff  MaxEntScan_ref  \
# 0      20.400             NaN              NaN             NaN
# 1      23.400             NaN              NaN             NaN
# 2      25.400             NaN              NaN             NaN
# 3       9.051             NaN              NaN             NaN
# 4      22.100             NaN              NaN             NaN
#
#    SpliceAI_pred_DP_AG  SpliceAI_pred_DP_AL  SpliceAI_pred_DP_DG  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                 21.0                -44.0                -45.0
# 4                 16.0                -14.0                 10.0
#
#    SpliceAI_pred_DP_DL  SpliceAI_pred_DS_AG  SpliceAI_pred_DS_AL  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                 45.0                  0.0                  0.0
# 4                 26.0                  0.0                  0.0
#
#    SpliceAI_pred_DS_DG  SpliceAI_pred_DS_DL  BLOSUM62  LOEUF  mutfunc_exp  \
# 0                  NaN                  NaN       2.0  0.305          NaN
# 1                  NaN                  NaN       0.0  0.550          NaN
# 2                  NaN                  NaN      -1.0  0.319          NaN
# 3                  0.0                  0.0       NaN  0.475     -0.01879
# 4                  0.0                  0.0       1.0  0.128          NaN
#
#    ada_score  Hit_class_encoded
# 0        NaN                  1
# 1        NaN                  1
# 2        NaN                  1
# 3        NaN                  1
# 4        NaN                  1

# %% [markdown]
# ## Split by Cell Lines

# %%
annotated_control_vs_plasmid_EG_HT29 = annotated_control_vs_plasmid_EG[annotated_control_vs_plasmid_EG['Cell_Line'] == 'HT29']
annotated_control_vs_plasmid_EG_A375 = annotated_control_vs_plasmid_EG[annotated_control_vs_plasmid_EG['Cell_Line'] == 'A375']

# %%
print(f'HT29 shape: {annotated_control_vs_plasmid_EG_HT29.shape}')
print(f'A375 shape: {annotated_control_vs_plasmid_EG_A375.shape}')
# Out:
# HT29 shape: (14043, 60)
# A375 shape: (14043, 60)

# %% [markdown]
# # Encode Labels

# %%
le = LabelEncoder()
annotated_control_vs_plasmid_EG['Hit_class_encoded'] = le.fit_transform(annotated_control_vs_plasmid_EG['Hit_class'])

# %%
# For each cell line
annotated_control_vs_plasmid_EG_HT29['Hit_class_encoded'] = le.transform(annotated_control_vs_plasmid_EG_HT29['Hit_class'])
annotated_control_vs_plasmid_EG_A375['Hit_class_encoded'] = le.transform(annotated_control_vs_plasmid_EG_A375['Hit_class'])
# Out:
# /var/folders/ry/v0cp3ptj55qfs_pd6_cghmzm0000gn/T/ipykernel_44325/1980557596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotated_control_vs_plasmid_EG_HT29['Hit_class_encoded'] = le.transform(annotated_control_vs_plasmid_EG_HT29['Hit_class'])
# /var/folders/ry/v0cp3ptj55qfs_pd6_cghmzm0000gn/T/ipykernel_44325/1980557596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotated_control_vs_plasmid_EG_A375['Hit_class_encoded'] = le.transform(annotated_control_vs_plasmid_EG_A375['Hit_class'])

# %%
# Check encoding mapping
label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

print("Label mapping:", label_mapping)
# Out:
# Label mapping: {'negative': np.int64(0), 'non-hit': np.int64(1), 'positive': np.int64(2)}

# %% [markdown]
# # Handle Class Imbalance

# %%
#combined dataset
class_counts = annotated_control_vs_plasmid_EG['Hit_class_encoded'].value_counts()
class_proportions = annotated_control_vs_plasmid_EG['Hit_class_encoded'].value_counts(normalize=True)

print("Class counts:\n", class_counts)
print("\nClass percentage:\n", (class_proportions*100).round(2))
# Out:
# Class counts:
#  Hit_class_encoded
# 1    27065
# 0      810
# 2      211
# Name: count, dtype: int64
#
# Class percentage:
#  Hit_class_encoded
# 1    96.36
# 0     2.88
# 2     0.75
# Name: proportion, dtype: float64

# %%
#HT29
class_counts_HT29 = annotated_control_vs_plasmid_EG_HT29['Hit_class_encoded'].value_counts()
class_proportions_HT29 = annotated_control_vs_plasmid_EG_HT29['Hit_class_encoded'].value_counts(normalize=True)

print("Class counts HT29:\n", class_counts_HT29)
print("\nClass percentage HT29:\n", (class_proportions_HT29*100).round(2))
# Out:
# Class counts HT29:
#  Hit_class_encoded
# 1    13430
# 0      450
# 2      163
# Name: count, dtype: int64
#
# Class percentage HT29:
#  Hit_class_encoded
# 1    95.63
# 0     3.20
# 2     1.16
# Name: proportion, dtype: float64

# %%
#A375
class_counts_A375 = annotated_control_vs_plasmid_EG_A375['Hit_class_encoded'].value_counts()
class_proportions_A375 = annotated_control_vs_plasmid_EG_A375['Hit_class_encoded'].value_counts(normalize=True)
print("Class counts A375:\n", class_counts_A375)
print("\nClass percentage A375:\n", (class_proportions_A375*100).round(2))
# Out:
# Class counts A375:
#  Hit_class_encoded
# 1    13635
# 0      360
# 2       48
# Name: count, dtype: int64
#
# Class percentage A375:
#  Hit_class_encoded
# 1    97.09
# 0     2.56
# 2     0.34
# Name: proportion, dtype: float64

# %%
counts_before_DS = (
    annotated_control_vs_plasmid_EG_A375
    .groupby(["Gene", "Hit_class"])
    .size()
    .reset_index(name="Count")
)

counts_non_hits_before_DS = counts_before_DS[counts_before_DS["Hit_class"] == "non-hit"]

plt.figure(figsize=(12,4))
sns.barplot(
    data=counts_non_hits_before_DS,
    x="Gene", y="Count", errorbar=None
)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Stratified Downsampling

# %%
df = annotated_control_vs_plasmid_EG.copy()

#Split dataset by class
df_negative = df[df['Hit_class'] == 'negative']
df_non_hit = df[df['Hit_class'] == 'non-hit']
df_positive = df[df['Hit_class'] == 'positive']

#Target number of non-hit samples to match negative samples
target_non_hit_count = 0.8*len(df_negative)

# Compute distribution of non-hits across Cell_Line × Gene
non_hit_distribution = (
    df_non_hit
    .groupby(['Cell_Line', 'Gene'])
    .size()
    .reset_index(name='Count')
)

# Calculate proportions
non_hit_distribution['Proportion'] = non_hit_distribution['Count'] / non_hit_distribution['Count'].sum()

# Determine number of samples to select from each Cell_Line × Gene
non_hit_distribution['Target'] = np.floor(non_hit_distribution['Proportion'] * target_non_hit_count).astype(int)

# Adjust target to ensure total matches target_non_hit_count - distribute the remaining samples to the groups with the largest fractional remainders
#difference = target_non_hit_count - non_hit_distribution['Target'].sum()
difference = int(round(target_non_hit_count - non_hit_distribution['Target'].sum()))

if difference > 0:
    fractional_parts = non_hit_distribution['Proportion'] * target_non_hit_count - non_hit_distribution['Target']
    top_idx = fractional_parts.nlargest(difference).index
    non_hit_distribution.loc[top_idx, 'Target'] += 1

#Perform stratified downsampling
downsampled_non_hits = []
for _, row in non_hit_distribution.iterrows():
    cell_line = row['Cell_Line']
    gene = row['Gene']
    target = row['Target']
    
    subset = df_non_hit[(df_non_hit['Cell_Line'] == cell_line) & (df_non_hit['Gene'] == gene)]

    if target > 0:
        n_sampled = min(target, len(subset)) # in case very small group
        downsampled_non_hits.append(subset.sample(n=n_sampled, random_state=1))
    
df_non_hit_downsampled = pd.concat(downsampled_non_hits, ignore_index=True)

# Combine downsampled non-hits with other classes
annotated_control_vs_plasmid_EG_balanced = pd.concat([df_negative, df_non_hit_downsampled, df_positive], ignore_index=True)

# %%
def stratified_downsampling(df, random_state=None):
    """
    Perform stratified downsampling of 'non-hit' class to match the size of the 'negative' class,
    stratified by (Cell_Line × Gene).
    
    Parameters
    ----------
    df : pd.DataFrame
        Original dataset with 'Hit_class', 'Cell_Line', and 'Gene'.
    random_state : int, optional
        Random seed for reproducibility of subsampling.

    Returns
    -------
    df_balanced : pd.DataFrame
        Balanced dataset containing all negatives, all positives, and downsampled non-hits.
    """
    #Split dataset by class
    df_negative = df[df['Hit_class'] == 'negative']
    df_non_hit = df[df['Hit_class'] == 'non-hit']
    df_positive = df[df['Hit_class'] == 'positive']

    #Target number of non-hit samples to match negative samples
    target_non_hit_count = len(df_negative)

    # Compute distribution of non-hits across Cell_Line × Gene
    non_hit_distribution = (
        df_non_hit
        .groupby(['Cell_Line', 'Gene'])
        .size()
        .reset_index(name='Count')
    )

    # Calculate proportions
    non_hit_distribution['Proportion'] = non_hit_distribution['Count'] / non_hit_distribution['Count'].sum()

    # Determine number of samples to select from each Cell_Line × Gene
    non_hit_distribution['Target'] = np.floor(non_hit_distribution['Proportion'] * target_non_hit_count).astype(int)

    # Adjust target to ensure total matches target_non_hit_count - distribute the remaining samples to the groups with the largest fractional remainders
    difference = target_non_hit_count - non_hit_distribution['Target'].sum()

    if difference > 0:
        fractional_parts = non_hit_distribution['Proportion'] * target_non_hit_count - non_hit_distribution['Target']
        top_idx = fractional_parts.nlargest(difference).index
        non_hit_distribution.loc[top_idx, 'Target'] += 1

    #Perform stratified downsampling
    downsampled_non_hits = []
    for _, row in non_hit_distribution.iterrows():
        cell_line = row['Cell_Line']
        gene = row['Gene']
        target = row['Target']
        
        subset = df_non_hit[(df_non_hit['Cell_Line'] == cell_line) & (df_non_hit['Gene'] == gene)]

        if target > 0:
            n_sampled = min(target, len(subset)) # in case very small group
            downsampled_non_hits.append(subset.sample(n=n_sampled, random_state=random_state))
        
    df_non_hit_downsampled = pd.concat(downsampled_non_hits, ignore_index=True)

    # Combine downsampled non-hits with other classes
    df_balanced = pd.concat([df_negative, df_non_hit_downsampled, df_positive], ignore_index=True)

    return df_balanced

# %%
print("Final class counts:")
print(annotated_control_vs_plasmid_EG_balanced["Hit_class"].value_counts())
# Out:
# Final class counts:
# Hit_class
# negative    810
# non-hit     648
# positive    211
# Name: count, dtype: int64

# %%
annotated_control_vs_plasmid_EG_balanced.head()
# Out:
#                   Guide Editor   Gene Cell_Line Drug    zscore Hit_class  \
# 0  AAAATCTGTAAGGGAAGAGA    CBE  IGF1R      A375   DO -2.054192  negative
# 1  AAAGCAGTCCCCAAAGTCAA    CBE   MTOR      A375   DO -3.851780  negative
# 2  AAAGGCAGGGTTCATGCTAC    CBE   MTOR      A375   DO -4.273213  negative
# 3  AAAGGCATGTTTGAGGTGCT    CBE   MTOR      A375   DO -4.732194  negative
# 4  AAATCTGTAAGGGAAGAGAG    CBE  IGF1R      A375   DO -1.109615  negative
#
#   Target Transcript ID RefSeq match transcript (MANE Select) Amino Acid Edits  \
# 0    ENST00000650285.1                           NM_000875.5             (NC)
# 1    ENST00000361445.9                           NM_004958.4       Cys2361Tyr
# 2    ENST00000361445.9                           NM_004958.4        Ala724Thr
# 3    ENST00000361445.9                           NM_004958.4       Gly2046Gly
# 4    ENST00000650285.1                           NM_000875.5             (NC)
#
#    Mutation_Category_enc  IMPACT_enc  TSL  SIFT_pathogenicity  \
# 0                    5.0         3.0  NaN                 NaN
# 1                    3.0         2.0  1.0                 0.0
# 2                    3.0         2.0  1.0                 0.0
# 3                    2.0         1.0  1.0                 NaN
# 4                    5.0         3.0  NaN                 NaN
#
#    PolyPhen_pathogenicity  REVEL  ClinPred  am_pathogenicity  EVE_SCORE  \
# 0                     NaN    NaN       NaN               NaN        NaN
# 1                     NaN  0.876  0.999938            0.9997   0.983177
# 2                   0.995  0.430  0.944457            0.9638   0.806266
# 3                     NaN    NaN       NaN               NaN        NaN
# 4                     NaN    NaN       NaN               NaN        NaN
#
#    BayesDel_noAF_score  DANN_score  DEOGEN2_score  ESM1b_score  \
# 0                  NaN         NaN            NaN          NaN
# 1             0.376218    0.998253       0.901346      -14.646
# 2             0.006105    0.999447       0.782876       -7.062
# 3                  NaN         NaN            NaN          NaN
# 4                  NaN         NaN            NaN          NaN
#
#    Eigen-PC-phred_coding  Eigen-PC-raw_coding  GERP++_NR  GERP++_RS  \
# 0                    NaN                  NaN        NaN        NaN
# 1                16.6271             0.960830       5.51       5.51
# 2                11.7622             0.849728       5.70       5.70
# 3                    NaN                  NaN        NaN        NaN
# 4                    NaN                  NaN        NaN        NaN
#
#    LIST-S2_score  MPC_rankscore  MPC_score  MVP_score  MetaRNN_score  \
# 0            NaN            NaN        NaN        NaN            NaN
# 1       0.963704        0.99644   3.350520   0.949545       0.947140
# 2       0.909909        0.88192   1.573937   0.683547       0.892936
# 3            NaN            NaN        NaN        NaN            NaN
# 4            NaN            NaN        NaN        NaN            NaN
#
#    MetaSVM_score  MutFormer_score  MutationAssessor_score  PROVEAN_score  \
# 0            NaN              NaN                     NaN            NaN
# 1         0.8686         0.996138                    4.49          -9.76
# 2        -0.2861         0.082219                    3.48          -3.64
# 3            NaN              NaN                     NaN            NaN
# 4            NaN              NaN                     NaN            NaN
#
#    PrimateAI_pred_enc  VARITY_R_LOO_score  bStatistic  fathmm-XF_coding_score  \
# 0                 NaN                 NaN         NaN                     NaN
# 1                 0.0            0.992620       403.0                0.892481
# 2                 0.0            0.899651       291.0                0.857350
# 3                 NaN                 NaN         NaN                     NaN
# 4                 NaN                 NaN         NaN                     NaN
#
#    gMVP_score  phastCons100way_vertebrate  phyloP100way_vertebrate  \
# 0         NaN                         NaN                      NaN
# 1    0.998039                         1.0                    7.248
# 2    0.640744                         1.0                    7.478
# 3         NaN                         NaN                      NaN
# 4         NaN                         NaN                      NaN
#
#    CADD_PHRED  MaxEntScan_alt  MaxEntScan_diff  MaxEntScan_ref  \
# 0        31.0           5.162             8.75          13.913
# 1        27.8             NaN              NaN             NaN
# 2        25.8             NaN              NaN             NaN
# 3        23.2             NaN              NaN             NaN
# 4        31.0           5.162             8.75          13.913
#
#    SpliceAI_pred_DP_AG  SpliceAI_pred_DP_AL  SpliceAI_pred_DP_DG  \
# 0                 -1.0                  1.0                 34.0
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                 -1.0                  1.0                 34.0
#
#    SpliceAI_pred_DP_DL  SpliceAI_pred_DS_AG  SpliceAI_pred_DS_AL  \
# 0                 18.0                 0.02                  1.0
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                 18.0                 0.02                  1.0
#
#    SpliceAI_pred_DS_DG  SpliceAI_pred_DS_DL  BLOSUM62  LOEUF  mutfunc_exp  \
# 0                  0.0                  0.0       NaN  0.330          NaN
# 1                  NaN                  NaN      -2.0  0.268          NaN
# 2                  NaN                  NaN       0.0  0.268          NaN
# 3                  NaN                  NaN       NaN  0.268          0.0
# 4                  0.0                  0.0       NaN  0.330          NaN
#
#    ada_score  Hit_class_encoded
# 0   0.999986                  0
# 1        NaN                  0
# 2        NaN                  0
# 3        NaN                  0
# 4   0.999986                  0

# %%
#Check distribution of non-hits after downsampling

counts_after_DS = (
    annotated_control_vs_plasmid_EG_A375_balanced
    .groupby(["Gene", "Hit_class"])
    .size()
    .reset_index(name="Count")
)

counts_non_hits_after_DS = counts_after_DS[counts_after_DS["Hit_class"] == "non-hit"]

plt.figure(figsize=(12,4))
sns.barplot(
    data=counts_non_hits_after_DS,
    x="Gene", y="Count", errorbar=None
)

plt.xticks(rotation=90)
plt.show()

# %%
#Create a df to compare the proportins of each class before and after downsampling
comparison_df = pd.DataFrame({
    'Before_Downsampling': annotated_control_vs_plasmid_EG_HT29['Hit_class'].value_counts(normalize=True).sort_index() * 100,
    'After_Downsampling': annotated_control_vs_plasmid_EG_HT29_balanced['Hit_class'].value_counts(normalize=True).sort_index() * 100
}).reset_index().rename(columns={'index': 'Hit_class'})

# %%
#Create a df to compare the proportins of each class before and after downsampling
comparison_df = pd.DataFrame({
    'Before_Downsampling': annotated_control_vs_plasmid_EG_HT29['Hit_class'].value_counts().sort_index(),
    'After_Downsampling': annotated_control_vs_plasmid_EG_HT29_balanced['Hit_class'].value_counts().sort_index()
}).reset_index().rename(columns={'index': 'Hit_class'})

# %%
comparison_df
# Out:
#   Hit_class  Before_Downsampling  After_Downsampling
# 0  negative                  450                 450
# 1   non-hit                13430                 450
# 2  positive                  163                 163

# %%
#Create a df to compare the proportions of each gene x cell line group in the non-hits class before and after downsampling
non_hit_comparison_df = pd.DataFrame({
    'Before_Downsampling': counts_non_hits_before_DS.set_index(['Cell_Line', 'Gene'])['Count'],
    'After_Downsampling': counts_non_hits_after_DS.set_index(['Cell_Line', 'Gene'])['Count']
}).reset_index()

# %%
non_hit_comparison_df = pd.DataFrame({
    'Before_Downsampling': counts_non_hits_before_DS.set_index(['Gene'])['Count'],
    'After_Downsampling': counts_non_hits_after_DS.set_index(['Gene'])['Count']
}).reset_index()

# %%
non_hit_comparison_df
# Out:
#       Gene  Before_Downsampling  After_Downsampling
# 0     AKT1                  308                   8
# 1     BRAF                  313                   8
# 2     EGFR                  696                  18
# 3    ERBB2                  845                  22
# 4    ERBB3                  888                  23
# 5    FGFR2                  446                  12
# 6     GAB1                  341                   9
# 7     GRB2                  142                   4
# 8     HRAS                  115                   3
# 9    IGF1R                  707                  19
# 10   ITGA3                  709                  19
# 11    KRAS                   85                   2
# 12  MAP2K1                  225                   6
# 13  MAP2K2                  258                   7
# 14   MAPK1                  173                   5
# 15   MAPK3                  247                   6
# 16    MTOR                 1419                  37
# 17     MYC                  231                   6
# 18     NF1                 1365                  36
# 19    NRAS                   98                   3
# 20     PGD                  260                   7
# 21  PHLDA2                  109                   3
# 22  PIK3CA                  448                  12
# 23  PIK3CB                  455                  12
# 24  PIK3CD                  733                  19
# 25     PKM                  294                   8
# 26    PTEN                  180                   5
# 27    RAF1                  361                  10
# 28  RICTOR                  770                  20
# 29    SHC1                  414                  11

# %%
# Compute proportions within each group (Cell_Line × Gene)
prop_before = counts_non_hits_before_DS.copy()
prop_before["Proportion_before_DS"] = round(prop_before["Count"] / prop_before["Count"].sum(),4)
prop_before = prop_before[["Cell_Line", "Gene", "Proportion_before_DS"]]

prop_after = counts_non_hits_after_DS.copy()
prop_after["Proportion_after_DS"] = round(prop_after["Count"] / prop_after["Count"].sum(), 4)
prop_after = prop_after[["Cell_Line", "Gene", "Proportion_after_DS"]]


prop_compare = pd.merge(prop_before, prop_after,
                        on=["Cell_Line", "Gene"], how="inner")

# Correlation of proportions
corr = prop_compare["Proportion_before_DS"].corr(prop_compare["Proportion_after_DS"])

print("Correlation of per-group proportions (before vs after downsampling):", round(corr, 4))
print("\nProportion comparison (first 20 rows):")
print(prop_compare.head(20))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 4
#       2 prop_before = counts_non_hits_before_DS.copy()
#       3 prop_before["Proportion_before_DS"] = round(prop_before["Count"] / prop_before["Count"].sum(),4)
# ----> 4 prop_before = prop_before[["Cell_Line", "Gene", "Proportion_before_DS"]]
#       6 prop_after = counts_non_hits_after_DS.copy()
#       7 prop_after["Proportion_after_DS"] = round(prop_after["Count"] / prop_after["Count"].sum(), 4)
#
# File ~/Desktop/Tese/BECancerResistome/venv/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Desktop/Tese/BECancerResistome/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Desktop/Tese/BECancerResistome/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Cell_Line'] not in index"

# %%
# for the specific cell lines
# Compute proportions within each group (Cell_Line × Gene)
prop_before = counts_non_hits_before_DS.copy()
prop_before["Proportion_before_DS"] = round(prop_before["Count"] / prop_before["Count"].sum(),4)
prop_before = prop_before[["Gene", "Proportion_before_DS"]]

prop_after = counts_non_hits_after_DS.copy()
prop_after["Proportion_after_DS"] = round(prop_after["Count"] / prop_after["Count"].sum(), 4)
prop_after = prop_after[["Gene", "Proportion_after_DS"]]


prop_compare = pd.merge(prop_before, prop_after,
                        on="Gene", how="inner")

# Correlation of proportions
corr = prop_compare["Proportion_before_DS"].corr(prop_compare["Proportion_after_DS"])

print("Correlation of gene proportions (before vs after downsampling) for HT29:", round(corr, 4))
print("\nProportion comparison (first 20 rows):")
print(prop_compare.head(20))
# Out:
# Correlation of gene proportions (before vs after downsampling) for HT29: 0.9996
#
# Proportion comparison (first 20 rows):
#       Gene  Proportion_before_DS  Proportion_after_DS
# 0     AKT1                0.0228               0.0222
# 1     BRAF                0.0235               0.0244
# 2     EGFR                0.0504               0.0511
# 3    ERBB2                0.0624               0.0622
# 4    ERBB3                0.0658               0.0667
# 5    FGFR2                0.0331               0.0333
# 6     GAB1                0.0253               0.0244
# 7     GRB2                0.0105               0.0111
# 8     HRAS                0.0086               0.0089
# 9    IGF1R                0.0468               0.0467
# 10   ITGA3                0.0523               0.0533
# 11    KRAS                0.0062               0.0067
# 12  MAP2K1                0.0166               0.0156
# 13  MAP2K2                0.0189               0.0200
# 14   MAPK1                0.0126               0.0133
# 15   MAPK3                0.0185               0.0178
# 16    MTOR                0.1074               0.1067
# 17     MYC                0.0167               0.0178
# 18     NF1                0.0999               0.1000
# 19    NRAS                0.0072               0.0067

# %%
# for the specific cell lines
# Compute proportions within each group (Cell_Line × Gene)
prop_before = counts_non_hits_before_DS.copy()
prop_before["Proportion_before_DS"] = round(prop_before["Count"] / prop_before["Count"].sum(),4)
prop_before = prop_before[["Gene", "Proportion_before_DS"]]

prop_after = counts_non_hits_after_DS.copy()
prop_after["Proportion_after_DS"] = round(prop_after["Count"] / prop_after["Count"].sum(), 4)
prop_after = prop_after[["Gene", "Proportion_after_DS"]]


prop_compare = pd.merge(prop_before, prop_after,
                        on="Gene", how="inner")

# Correlation of proportions
corr = prop_compare["Proportion_before_DS"].corr(prop_compare["Proportion_after_DS"])

print("Correlation of gene proportions (before vs after downsampling) for A375:", round(corr, 4))
print("\nProportion comparison (first 20 rows):")
print(prop_compare.head(20))
# Out:
# Correlation of gene proportions (before vs after downsampling) for A375: 0.9996
#
# Proportion comparison (first 20 rows):
#       Gene  Proportion_before_DS  Proportion_after_DS
# 0     AKT1                0.0226               0.0222
# 1     BRAF                0.0230               0.0222
# 2     EGFR                0.0510               0.0500
# 3    ERBB2                0.0620               0.0611
# 4    ERBB3                0.0651               0.0639
# 5    FGFR2                0.0327               0.0333
# 6     GAB1                0.0250               0.0250
# 7     GRB2                0.0104               0.0111
# 8     HRAS                0.0084               0.0083
# 9    IGF1R                0.0519               0.0528
# 10   ITGA3                0.0520               0.0528
# 11    KRAS                0.0062               0.0056
# 12  MAP2K1                0.0165               0.0167
# 13  MAP2K2                0.0189               0.0194
# 14   MAPK1                0.0127               0.0139
# 15   MAPK3                0.0181               0.0167
# 16    MTOR                0.1041               0.1028
# 17     MYC                0.0169               0.0167
# 18     NF1                0.1001               0.1000
# 19    NRAS                0.0072               0.0083

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Split into Features (X) and labels (y)

# %%
#Define meta data columns to drop
meta_cols=[
    'Target Transcript ID', 'RefSeq match transcript (MANE Select)', 'Guide', 'Editor', 'Gene', 'Cell_Line','Drug', 'Amino Acid Edits', 
    'Hit_class', 'zscore', 'Hit_class'
]

#Split into features and labels
X = annotated_control_vs_plasmid_EG_balanced.drop(columns=meta_cols + ["Hit_class_encoded"])
y = annotated_control_vs_plasmid_EG_balanced["Hit_class_encoded"]

print("Feature matrix shape:", X.shape)
print("Label vector shape:", y.shape)
# Out:
# Feature matrix shape: (2236, 49)
# Label vector shape: (2236,)

# %%
#for specific cell lines
X_ht29 = annotated_control_vs_plasmid_EG_HT29_balanced.drop(columns=meta_cols + ["Hit_class_encoded"])
y_ht29 = annotated_control_vs_plasmid_EG_HT29_balanced["Hit_class_encoded"]

X_a375 = annotated_control_vs_plasmid_EG_A375_balanced.drop(columns=meta_cols + ["Hit_class_encoded"])
y_a375 = annotated_control_vs_plasmid_EG_A375_balanced["Hit_class_encoded"]

print("Feature matrix shape HT29:", X_ht29.shape)
print("Label vector shape HT29:", y_ht29.shape)
print("Feature matrix shape A375:", X_a375.shape)
print("Label vector shape A375:", y_a375.shape)
# Out:
# Feature matrix shape HT29: (1063, 49)
# Label vector shape HT29: (1063,)
# Feature matrix shape A375: (768, 49)
# Label vector shape A375: (768,)

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Hit_class_encoded, dtype: int64

# %%
X_a375.head()
# Out:
#    Mutation_Category_enc  IMPACT_enc  TSL  SIFT_pathogenicity  \
# 0                    5.0         3.0  NaN                 NaN
# 1                    3.0         2.0  1.0                 0.0
# 2                    3.0         2.0  1.0                 0.0
# 3                    2.0         1.0  1.0                 NaN
# 4                    5.0         3.0  NaN                 NaN
#
#    PolyPhen_pathogenicity  REVEL  ClinPred  am_pathogenicity  EVE_SCORE  \
# 0                     NaN    NaN       NaN               NaN        NaN
# 1                     NaN  0.876  0.999938            0.9997   0.983177
# 2                   0.995  0.430  0.944457            0.9638   0.806266
# 3                     NaN    NaN       NaN               NaN        NaN
# 4                     NaN    NaN       NaN               NaN        NaN
#
#    BayesDel_noAF_score  DANN_score  DEOGEN2_score  ESM1b_score  \
# 0                  NaN         NaN            NaN          NaN
# 1             0.376218    0.998253       0.901346      -14.646
# 2             0.006105    0.999447       0.782876       -7.062
# 3                  NaN         NaN            NaN          NaN
# 4                  NaN         NaN            NaN          NaN
#
#    Eigen-PC-phred_coding  Eigen-PC-raw_coding  GERP++_NR  GERP++_RS  \
# 0                    NaN                  NaN        NaN        NaN
# 1                16.6271             0.960830       5.51       5.51
# 2                11.7622             0.849728       5.70       5.70
# 3                    NaN                  NaN        NaN        NaN
# 4                    NaN                  NaN        NaN        NaN
#
#    LIST-S2_score  MPC_rankscore  MPC_score  MVP_score  MetaRNN_score  \
# 0            NaN            NaN        NaN        NaN            NaN
# 1       0.963704        0.99644   3.350520   0.949545       0.947140
# 2       0.909909        0.88192   1.573937   0.683547       0.892936
# 3            NaN            NaN        NaN        NaN            NaN
# 4            NaN            NaN        NaN        NaN            NaN
#
#    MetaSVM_score  MutFormer_score  MutationAssessor_score  PROVEAN_score  \
# 0            NaN              NaN                     NaN            NaN
# 1         0.8686         0.996138                    4.49          -9.76
# 2        -0.2861         0.082219                    3.48          -3.64
# 3            NaN              NaN                     NaN            NaN
# 4            NaN              NaN                     NaN            NaN
#
#    PrimateAI_pred_enc  VARITY_R_LOO_score  bStatistic  fathmm-XF_coding_score  \
# 0                 NaN                 NaN         NaN                     NaN
# 1                 0.0            0.992620       403.0                0.892481
# 2                 0.0            0.899651       291.0                0.857350
# 3                 NaN                 NaN         NaN                     NaN
# 4                 NaN                 NaN         NaN                     NaN
#
#    gMVP_score  phastCons100way_vertebrate  phyloP100way_vertebrate  \
# 0         NaN                         NaN                      NaN
# 1    0.998039                         1.0                    7.248
# 2    0.640744                         1.0                    7.478
# 3         NaN                         NaN                      NaN
# 4         NaN                         NaN                      NaN
#
#    CADD_PHRED  MaxEntScan_alt  MaxEntScan_diff  MaxEntScan_ref  \
# 0        31.0           5.162             8.75          13.913
# 1        27.8             NaN              NaN             NaN
# 2        25.8             NaN              NaN             NaN
# 3        23.2             NaN              NaN             NaN
# 4        31.0           5.162             8.75          13.913
#
#    SpliceAI_pred_DP_AG  SpliceAI_pred_DP_AL  SpliceAI_pred_DP_DG  \
# 0                 -1.0                  1.0                 34.0
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                 -1.0                  1.0                 34.0
#
#    SpliceAI_pred_DP_DL  SpliceAI_pred_DS_AG  SpliceAI_pred_DS_AL  \
# 0                 18.0                 0.02                  1.0
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                 18.0                 0.02                  1.0
#
#    SpliceAI_pred_DS_DG  SpliceAI_pred_DS_DL  BLOSUM62  LOEUF  mutfunc_exp  \
# 0                  0.0                  0.0       NaN  0.330          NaN
# 1                  NaN                  NaN      -2.0  0.268          NaN
# 2                  NaN                  NaN       0.0  0.268          NaN
# 3                  NaN                  NaN       NaN  0.268          0.0
# 4                  0.0                  0.0       NaN  0.330          NaN
#
#    ada_score
# 0   0.999986
# 1        NaN
# 2        NaN
# 3        NaN
# 4   0.999986

# %%
#Check missing values again
X_info = pd.DataFrame({
    'dtype': X.dtypes,
    'non-null count': X.notna().sum(),
    'missing (%)': X.isna().mean() * 100,
    'n_unique': X.nunique(),
    'example': X.apply(lambda col: col.dropna().unique()[:3])
}).sort_values('missing (%)', ascending=True)

print(f'{len(X)} rows and {len(X.columns)} columns')
X_info

# %% [markdown]
# ## Baseline

# %%
#first with no hyperparameter tuning
xgb_classifier = XGBClassifier(random_state=1)

#Model with optimized hyperparameters for A375
xgb_classifier_optimized_a375 = XGBClassifier(
    subsample=0.85,
    reg_lambda=0.7,
    reg_alpha=0,
    n_estimators=300,
    min_child_weight=3,
    max_depth=6,
    learning_rate=0.1,
    colsample_bytree=1,
    objective="multi:softprob",   
    num_class=len(le.classes_),   
    random_state=1,
    n_jobs=-1                    
)

#Model with optimized hyperparameters for Ht29
xgb_classifier_optimized_ht29 = XGBClassifier(
    subsample=1.0,
    reg_lambda=1.3,
    reg_alpha=1,
    n_estimators=1000,
    min_child_weight=1,
    max_depth=9,
    learning_rate=0.01,
    colsample_bytree=1,
    objective="multi:softprob",   
    num_class=len(le.classes_),   
    random_state=1,
    n_jobs=-1                    
)

#Model with optimized hyperparameters 
xgb_classifier_optimized = XGBClassifier(
    subsample=0.85,
    reg_lambda=0.5,
    reg_alpha=1,
    n_estimators=700,
    min_child_weight=1,
    max_depth=9,
    learning_rate=0.01,
    colsample_bytree=0.85,
    objective="multi:softprob",   
    num_class=len(le.classes_),   
    random_state=1,
    n_jobs=-1                    
)

#Model with optimized hyperparameters 
xgb_classifier_optimized_bayesian = XGBClassifier(
    subsample=0.9167449779875692,
    reg_lambda=2.0,
    reg_alpha=0.08430984461758138,
    n_estimators=2000,
    min_child_weight=2,
    max_depth=9,
    learning_rate=0.016988937755638818,
    colsample_bytree=0.8354720212782338,
    objective="multi:softprob",   
    num_class=len(le.classes_),   
    random_state=1,
    n_jobs=-1                    
)

#Stratified 5-fold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

#colect predictions and true labels for each fold + metrics
fold_classif_reports = []
roc_auc_scores_weighted = []
roc_auc_scores_macro = []
pr_auc_scores_weighted = []
pr_auc_scores_macro = []
all_y_true = []
all_y_pred = []


for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    xgb_classifier_optimized.fit(X_train, y_train)
    y_pred = xgb_classifier_optimized.predict(X_val)
    probs = xgb_classifier_optimized.predict_proba(X_val) 

    #ROC AUC
    roc_auc_weighted = roc_auc_score(y_val, probs, multi_class="ovr", average='weighted')
    roc_auc_macro = roc_auc_score(y_val, probs, multi_class="ovr", average='macro')
    roc_auc_scores_weighted.append(roc_auc_weighted)
    roc_auc_scores_macro.append(roc_auc_macro)

    #PR AUC
    pr_auc_weighted = average_precision_score(y_val, probs, average='weighted')
    pr_auc_macro = average_precision_score(y_val, probs, average='macro')

    pr_auc_scores_weighted.append(pr_auc_weighted)
    pr_auc_scores_macro.append(pr_auc_macro)


    all_y_true.extend(y_val)
    all_y_pred.extend(y_pred)

    report = classification_report(y_val, y_pred, target_names=le.classes_, output_dict=True)
    fold_classif_reports.append(report)

    print(f"\n=== Fold {fold+1} ===")
    print(classification_report(y_val, y_pred, target_names=le.classes_, digits=3))
    print(f"ROC AUC (weighted): {roc_auc_weighted:.3f}")
    print(f"PR AUC (weighted): {pr_auc_weighted:.3f}")
# Out:
# === Fold 1 ===
#               precision    recall  f1-score   support
#
#     negative      0.818     0.858     0.837       162
#      non-hit      0.830     0.885     0.857       243
#     positive      0.789     0.349     0.484        43
#
#     accuracy                          0.824       448
#    macro avg      0.812     0.697     0.726       448
# weighted avg      0.822     0.824     0.814       448
#
# ROC AUC (weighted): 0.895
# PR AUC (weighted): 0.841
#
# === Fold 2 ===
#               precision    recall  f1-score   support
#
#     negative      0.818     0.802     0.810       162
#      non-hit      0.797     0.889     0.840       243
#     positive      0.824     0.333     0.475        42
#
#     accuracy                          0.805       447
#    macro avg      0.813     0.675     0.708       447
# weighted avg      0.807     0.805     0.795       447
#
# ROC AUC (weighted): 0.881
# PR AUC (weighted): 0.828
#
# === Fold 3 ===
#               precision    recall  f1-score   support
#
#     negative      0.865     0.833     0.849       162
#      non-hit      0.799     0.914     0.852       243
#     positive      0.769     0.238     0.364        42
#
#     accuracy                          0.821       447
#    macro avg      0.811     0.662     0.688       447
# weighted avg      0.820     0.821     0.805       447
#
# ROC AUC (weighted): 0.890
# PR AUC (weighted): 0.835
#
# === Fold 4 ===
#               precision    recall  f1-score   support
#
#     negative      0.857     0.815     0.835       162
#      non-hit      0.793     0.901     0.844       243
#     positive      0.706     0.286     0.407        42
#
#     accuracy                          0.812       447
#    macro avg      0.786     0.667     0.695       447
# weighted avg      0.808     0.812     0.800       447
#
# ROC AUC (weighted): 0.884
# PR AUC (weighted): 0.824
#
# === Fold 5 ===
#               precision    recall  f1-score   support
#
#     negative      0.831     0.821     0.826       162
#      non-hit      0.812     0.905     0.856       243
#     positive      0.812     0.310     0.448        42
#
#     accuracy                          0.819       447
#    macro avg      0.819     0.679     0.710       447
# weighted avg      0.819     0.819     0.807       447
#
# ROC AUC (weighted): 0.898
# PR AUC (weighted): 0.857

# %%
# === Average metrics ===
avg_report = {}
avg_report["accuracy"] = np.mean([r["accuracy"] for r in fold_classif_reports])
avg_report["macro avg"] = {
    metric: np.mean([r["macro avg"][metric] for r in fold_classif_reports])
    for metric in ["precision", "recall", "f1-score"]
}
avg_report["weighted avg"] = {
    metric: np.mean([r["weighted avg"][metric] for r in fold_classif_reports])
    for metric in ["precision", "recall", "f1-score"]
}

avg_report["positive"] = {
    metric: np.mean([r["positive"][metric] for r in fold_classif_reports])
    for metric in ["precision", "recall", "f1-score"]
}
avg_report["negative"] = {
    metric: np.mean([r["negative"][metric] for r in fold_classif_reports])
    for metric in ["precision", "recall", "f1-score"]
}
avg_report["non-hit"] = {
    metric: np.mean([r["non-hit"][metric] for r in fold_classif_reports])
    for metric in ["precision", "recall", "f1-score"]
}

avg_roc_auc_weighthed = np.mean(roc_auc_scores_weighted)
avg_roc_auc_macro = np.mean(roc_auc_scores_macro)

avg_pr_auc_weighthed = np.mean(pr_auc_scores_weighted)
avg_pr_auc_macro = np.mean(pr_auc_scores_macro)

def round_dict(d, ndigits=3):
    return {k: round(float(v), ndigits) for k, v in d.items()}

print("\n=== Average CV Results ===")
print("Accuracy:", round(float(avg_report["accuracy"]), 3))
print("ROC AUC (weighted):", round(float(avg_roc_auc_weighthed), 3))
print("ROC AUC (macro):", round(float(avg_roc_auc_macro), 3))
print("PR AUC (weighted):", round(float(avg_pr_auc_weighthed), 3))
print("PR AUC (macro):", round(float(avg_pr_auc_macro), 3))
print("\nClass-wise metrics:")
print("Positive:", round_dict(avg_report["positive"]))
print("Negative:", round_dict(avg_report["negative"]))
print("Non-hit:", round_dict(avg_report["non-hit"]))
print("\nMacro Avg:", round_dict(avg_report["macro avg"]))
print("Weighted Avg:", round_dict(avg_report["weighted avg"]))
# Out:
# === Average CV Results ===
# Accuracy: 0.816
# ROC AUC (weighted): 0.889
# ROC AUC (macro): 0.864
# PR AUC (weighted): 0.837
# PR AUC (macro): 0.741
#
# Class-wise metrics:
# Positive: {'precision': 0.78, 'recall': 0.303, 'f1-score': 0.435}
# Negative: {'precision': 0.838, 'recall': 0.826, 'f1-score': 0.832}
# Non-hit: {'precision': 0.806, 'recall': 0.899, 'f1-score': 0.85}
#
# Macro Avg: {'precision': 0.808, 'recall': 0.676, 'f1-score': 0.706}
# Weighted Avg: {'precision': 0.815, 'recall': 0.816, 'f1-score': 0.804}

# %%
# Single-run confusion matrix plotting
cm = confusion_matrix(all_y_true, all_y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.xlabel("Predicted Label", fontsize=9)
plt.ylabel("True Label", fontsize=9)
plt.show()

# %%
# Extract precision and recall per class from avg_report
class_names = ["negative", "non-hit", "positive"]

precision_means = [avg_report[c]["precision"] for c in class_names]
recall_means    = [avg_report[c]["recall"] for c in class_names]

x = np.arange(len(class_names))  # positions
width = 0.35  # bar width

plt.figure(figsize=(6,5))
bars1 = plt.bar(x - width/2, precision_means, width, label="Precision", color="lightsteelblue")
bars2 = plt.bar(x + width/2, recall_means, width, label="Recall", color="midnightblue")

# Add numbers on top of bars
for bar in bars1:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.01, 
             f"{height:.2f}", ha='center', va='bottom', fontsize=8)

for bar in bars2:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.01, 
             f"{height:.2f}", ha='center', va='bottom', fontsize=8)

# Customize fonts
plt.xticks(x, class_names, fontsize=8)
plt.yticks(fontsize=8)
plt.ylabel("Score", fontsize=10)
#plt.title("Precision and Recall per Class (5-fold CV average)", fontsize=16)
plt.legend(loc="upper right", fontsize=6)

plt.ylim(0, 1.05)  # leave space for labels
plt.show()

# %% [markdown]
# ## Run with k downsamples

# %%
def train_test_once(df, model, meta_cols, le, cv, stratified_downsampling, random_state_for_downsampling):

    #Perform stratified downsampling
    df_balanced = stratified_downsampling(df, random_state=random_state_for_downsampling)

    #Separate train and test sets
    X = df_balanced.drop(columns=meta_cols + ["Hit_class_encoded"])
    y = df_balanced["Hit_class_encoded"]

    class_names = list(le.classes_)
    n_classes = len(class_names)

    fold_reports = []
    roc_auc_scores_weighted, roc_auc_scores_macro = [], []
    pr_auc_scores_weighted, pr_auc_scores_macro = [], []
    all_y_true, all_y_pred = [], []

    for fold, (train_idx, val_idx) in enumerate(cv.split(X, y)):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)
        probs = model.predict_proba(X_val) 

        #ROC AUC
        roc_auc_scores_weighted.append(roc_auc_score(y_val, probs, multi_class="ovr", average='weighted'))
        roc_auc_scores_macro.append(roc_auc_score(y_val, probs, multi_class="ovr", average='macro'))

        #PR AUC
        pr_auc_scores_weighted.append(average_precision_score(y_val, probs, average='weighted'))
        pr_auc_scores_macro.append(average_precision_score(y_val, probs, average='macro'))

        all_y_true.extend(y_val)
        all_y_pred.extend(y_pred)

        report = classification_report(y_val, y_pred, target_names=le.classes_, output_dict=True)
        fold_reports.append(report)

    # Aggregate metrics - average across folds 
    metrics = {}
    metrics["accuracy"] = np.mean([r["accuracy"] for r in fold_reports])

    for avg_key in ["macro avg", "weighted avg"]:
        metrics[f"precision_{avg_key}"] = np.mean([r[avg_key]["precision"] for r in fold_reports])
        metrics[f"recall_{avg_key}"]    = np.mean([r[avg_key]["recall"] for r in fold_reports])
        metrics[f"f1_{avg_key}"]        = np.mean([r[avg_key]["f1-score"] for r in fold_reports])

    for cname in class_names:
        metrics[f"precision_{cname}"] = np.mean([r[cname]["precision"] for r in fold_reports])
        metrics[f"recall_{cname}"]    = np.mean([r[cname]["recall"]    for r in fold_reports])
        metrics[f"f1_{cname}"]        = np.mean([r[cname]["f1-score"]  for r in fold_reports])

    metrics["roc_auc_weighted"] = np.mean(roc_auc_scores_weighted)
    metrics["roc_auc_macro"]    = np.mean(roc_auc_scores_macro)
    metrics["pr_auc_weighted"]  = np.mean(pr_auc_scores_weighted)
    metrics["pr_auc_macro"]     = np.mean(pr_auc_scores_macro)

    #print(f'all-true:{all_y_true}')
    #print(f'all-pred:{all_y_pred}')

    cm = confusion_matrix(all_y_true, all_y_pred, labels=np.arange(len(le.classes_)))
    return metrics, cm

# %%
# Run multiple times to get average performance across different downsamplings
n_runs = 10
all_metrics = []
all_cms = []

xgb_classifier_optimized = XGBClassifier(
    subsample=0.85,
    reg_lambda=0.5,
    reg_alpha=1,
    n_estimators=700,
    min_child_weight=1,
    max_depth=9,
    learning_rate=0.01,
    colsample_bytree=0.85,
    objective="multi:softprob",   
    num_class=len(le.classes_),   
    random_state=1,
    n_jobs=-1                    
)

for i in range(n_runs):
    print(f"\n--- Run {i+1}/{n_runs} ---")
    metrics, cm = train_test_once(
        df=annotated_control_vs_plasmid_EG,
        model=xgb_classifier_optimized,
        meta_cols=meta_cols,
        le=le,
        cv=skf,
        stratified_downsampling=stratified_downsampling,
        random_state_for_downsampling=i  # Different seed for each run
    )
    all_metrics.append(metrics)
    all_cms.append(cm)
    print("Metrics:", metrics)
    print("Confusion Matrix:\n", cm)

# Aggregate metrics across runs
# Convert metrics into DataFrame for mean/std
metrics_df = pd.DataFrame(all_metrics)
metrics_mean = metrics_df.mean()
metrics_std = metrics_df.std()

cm_mean = np.mean(np.array(all_cms, dtype=float), axis=0)
cm_std = np.std(np.array(all_cms, dtype=float), axis=0)

print("=== Mean metrics ===")
print(metrics_mean)
print("\n=== Std metrics ===")
print(metrics_std)

print("\n=== Mean confusion matrix ===")
print(cm_mean)
print("\n=== Std confusion matrix ===")
print(cm_std)
# Out:
# --- Run 1/10 ---
# Metrics: {'accuracy': np.float64(0.7902681615818704), 'precision_macro avg': np.float64(0.7681969134340811), 'recall_macro avg': np.float64(0.6748355960242265), 'f1_macro avg': np.float64(0.6945531228923099), 'precision_weighted avg': np.float64(0.7884607730433186), 'recall_weighted avg': np.float64(0.7902681615818704), 'f1_weighted avg': np.float64(0.7787245602978559), 'precision_negative': np.float64(0.8463672221784868), 'recall_negative': np.float64(0.8481481481481481), 'f1_negative': np.float64(0.8467911676575858), 'precision_non-hit': np.float64(0.7518467065295537), 'recall_non-hit': np.float64(0.8543209876543211), 'f1_non-hit': np.float64(0.7995233236744663), 'precision_positive': np.float64(0.7063768115942028), 'recall_positive': np.float64(0.3220376522702104), 'f1_positive': np.float64(0.4373448773448773), 'roc_auc_weighted': np.float64(0.8900900787238957), 'roc_auc_macro': np.float64(0.8689574181948292), 'pr_auc_weighted': np.float64(0.8167490522014186), 'pr_auc_macro': np.float64(0.7352751085691883)}
# Confusion Matrix:
#  [[687 112  11]
#  [100 692  18]
#  [ 26 117  68]]
#
# --- Run 2/10 ---
# Metrics: {'accuracy': np.float64(0.8012015902086033), 'precision_macro avg': np.float64(0.7825807367765258), 'recall_macro avg': np.float64(0.6971384821514021), 'f1_macro avg': np.float64(0.7191153575380772), 'precision_weighted avg': np.float64(0.7994575098999582), 'recall_weighted avg': np.float64(0.8012015902086033), 'f1_weighted avg': np.float64(0.7922942164984578), 'precision_negative': np.float64(0.8525929131567571), 'recall_negative': np.float64(0.8654320987654321), 'f1_negative': np.float64(0.8586689297540282), 'precision_non-hit': np.float64(0.7641399804026342), 'recall_non-hit': np.float64(0.8469135802469137), 'f1_non-hit': np.float64(0.8032196007730731), 'precision_positive': np.float64(0.7310093167701863), 'recall_positive': np.float64(0.37906976744186044), 'f1_positive': np.float64(0.4954575420871305), 'roc_auc_weighted': np.float64(0.8961367195757459), 'roc_auc_macro': np.float64(0.8762615942553339), 'pr_auc_weighted': np.float64(0.8316761863567725), 'pr_auc_macro': np.float64(0.7587515211878262)}
# Confusion Matrix:
#  [[701 104   5]
#  [ 99 686  25]
#  [ 23 108  80]]
#
# --- Run 3/10 ---
# Metrics: {'accuracy': np.float64(0.7858921100043179), 'precision_macro avg': np.float64(0.759248451567764), 'recall_macro avg': np.float64(0.6762096167780922), 'f1_macro avg': np.float64(0.696327903395668), 'precision_weighted avg': np.float64(0.7824428668480334), 'recall_weighted avg': np.float64(0.7858921100043179), 'f1_weighted avg': np.float64(0.7757970452768973), 'precision_negative': np.float64(0.8433160918311214), 'recall_negative': np.float64(0.8518518518518517), 'f1_negative': np.float64(0.8473531137319654), 'precision_non-hit': np.float64(0.7460537253661981), 'recall_non-hit': np.float64(0.8358024691358026), 'f1_non-hit': np.float64(0.788173942918489), 'precision_positive': np.float64(0.6883755375059724), 'recall_positive': np.float64(0.34097452934662237), 'f1_positive': np.float64(0.4534566535365497), 'roc_auc_weighted': np.float64(0.8906116796472883), 'roc_auc_macro': np.float64(0.8719377182187344), 'pr_auc_weighted': np.float64(0.8180916433350405), 'pr_auc_macro': np.float64(0.7399240357419592)}
# Confusion Matrix:
#  [[690 113   7]
#  [107 677  26]
#  [ 22 117  72]]
#
# --- Run 4/10 ---
# Metrics: {'accuracy': np.float64(0.7837226962076206), 'precision_macro avg': np.float64(0.7415061693569698), 'recall_macro avg': np.float64(0.6675826805025772), 'f1_macro avg': np.float64(0.6849850749930576), 'precision_weighted avg': np.float64(0.7767259489135364), 'recall_weighted avg': np.float64(0.7837226962076206), 'f1_weighted avg': np.float64(0.7724476709131958), 'precision_negative': np.float64(0.8427784223922161), 'recall_negative': np.float64(0.8567901234567901), 'f1_negative': np.float64(0.8493242960008818), 'precision_non-hit': np.float64(0.7479495487302616), 'recall_non-hit': np.float64(0.8333333333333334), 'f1_non-hit': np.float64(0.7879678629586522), 'precision_positive': np.float64(0.6337905369484316), 'recall_positive': np.float64(0.312624584717608), 'f1_positive': np.float64(0.41766306601963893), 'roc_auc_weighted': np.float64(0.8897519847950066), 'roc_auc_macro': np.float64(0.8678994260393317), 'pr_auc_weighted': np.float64(0.8088738689151016), 'pr_auc_macro': np.float64(0.7245025090382184)}
# Confusion Matrix:
#  [[694 110   6]
#  [103 675  32]
#  [ 27 118  66]]
#
# --- Run 5/10 ---
# Metrics: {'accuracy': np.float64(0.7973719867184824), 'precision_macro avg': np.float64(0.7767311205806386), 'recall_macro avg': np.float64(0.6883420149570021), 'f1_macro avg': np.float64(0.7100514054685771), 'precision_weighted avg': np.float64(0.7955644788645739), 'recall_weighted avg': np.float64(0.7973719867184824), 'f1_weighted avg': np.float64(0.7874788102547825), 'precision_negative': np.float64(0.8548833887218101), 'recall_negative': np.float64(0.8493827160493825), 'f1_negative': np.float64(0.8518961184257148), 'precision_non-hit': np.float64(0.7561637741896964), 'recall_non-hit': np.float64(0.8604938271604936), 'f1_non-hit': np.float64(0.80481489059274), 'precision_positive': np.float64(0.7191461988304093), 'recall_positive': np.float64(0.3551495016611296), 'f1_positive': np.float64(0.47344320738727685), 'roc_auc_weighted': np.float64(0.8977516689081245), 'roc_auc_macro': np.float64(0.8780737101649108), 'pr_auc_weighted': np.float64(0.8263077490467625), 'pr_auc_macro': np.float64(0.7461800200366113)}
# Confusion Matrix:
#  [[688 113   9]
#  [ 93 697  20]
#  [ 24 112  75]]
#
# --- Run 6/10 ---
# Metrics: {'accuracy': np.float64(0.7837137624514228), 'precision_macro avg': np.float64(0.7411901095985797), 'recall_macro avg': np.float64(0.671073103372845), 'f1_macro avg': np.float64(0.6875445136011785), 'precision_weighted avg': np.float64(0.7777984270999009), 'recall_weighted avg': np.float64(0.7837137624514228), 'f1_weighted avg': np.float64(0.7734553181190786), 'precision_negative': np.float64(0.8439811682883398), 'recall_negative': np.float64(0.8567901234567902), 'f1_negative': np.float64(0.8500501811256529), 'precision_non-hit': np.float64(0.7502257508143962), 'recall_non-hit': np.float64(0.8296296296296296), 'f1_non-hit': np.float64(0.7875831449658116), 'precision_positive': np.float64(0.629363409693003), 'recall_positive': np.float64(0.3267995570321152), 'f1_positive': np.float64(0.42500021471207117), 'roc_auc_weighted': np.float64(0.8907364041231801), 'roc_auc_macro': np.float64(0.8709272146169542), 'pr_auc_weighted': np.float64(0.8211279056246292), 'pr_auc_macro': np.float64(0.7418062458584022)}
# Confusion Matrix:
#  [[694 104  12]
#  [107 672  31]
#  [ 22 120  69]]
#
# --- Run 7/10 ---
# Metrics: {'accuracy': np.float64(0.7820803740265928), 'precision_macro avg': np.float64(0.7603767999415271), 'recall_macro avg': np.float64(0.6686627565180537), 'f1_macro avg': np.float64(0.6871166437546916), 'precision_weighted avg': np.float64(0.7812568365874517), 'recall_weighted avg': np.float64(0.7820803740265928), 'f1_weighted avg': np.float64(0.7711598704126132), 'precision_negative': np.float64(0.8400582722910711), 'recall_negative': np.float64(0.8493827160493828), 'f1_negative': np.float64(0.8441864312705718), 'precision_non-hit': np.float64(0.7446618711232537), 'recall_non-hit': np.float64(0.8345679012345679), 'f1_non-hit': np.float64(0.7869138068811834), 'precision_positive': np.float64(0.6964102564102564), 'recall_positive': np.float64(0.32203765227021036), 'f1_positive': np.float64(0.4302496931123194), 'roc_auc_weighted': np.float64(0.8918326089397139), 'roc_auc_macro': np.float64(0.8716453195565042), 'pr_auc_weighted': np.float64(0.8210978731862302), 'pr_auc_macro': np.float64(0.7379320861829953)}
# Confusion Matrix:
#  [[688 113   9]
#  [108 676  26]
#  [ 24 119  68]]
#
# --- Run 8/10 ---
# Metrics: {'accuracy': np.float64(0.7831777370795551), 'precision_macro avg': np.float64(0.7572921066112244), 'recall_macro avg': np.float64(0.6672080718592346), 'f1_macro avg': np.float64(0.6869562916299476), 'precision_weighted avg': np.float64(0.7801646479692262), 'recall_weighted avg': np.float64(0.7831777370795551), 'f1_weighted avg': np.float64(0.7717352945335005), 'precision_negative': np.float64(0.8420590322566142), 'recall_negative': np.float64(0.8506172839506172), 'f1_negative': np.float64(0.8458951865365053), 'precision_non-hit': np.float64(0.742519134420782), 'recall_non-hit': np.float64(0.8382716049382717), 'f1_non-hit': np.float64(0.7871650115541519), 'precision_positive': np.float64(0.6872981531562768), 'recall_positive': np.float64(0.31273532668881504), 'f1_positive': np.float64(0.4278086767991859), 'roc_auc_weighted': np.float64(0.8841409186402778), 'roc_auc_macro': np.float64(0.8655761743177788), 'pr_auc_weighted': np.float64(0.8081466704519261), 'pr_auc_macro': np.float64(0.7342799578311081)}
# Confusion Matrix:
#  [[689 114   7]
#  [107 679  24]
#  [ 23 122  66]]
#
# --- Run 9/10 ---
# Metrics: {'accuracy': np.float64(0.7962746236655202), 'precision_macro avg': np.float64(0.7736664653081512), 'recall_macro avg': np.float64(0.687592797670317), 'f1_macro avg': np.float64(0.7091547253222459), 'precision_weighted avg': np.float64(0.7928485634499943), 'recall_weighted avg': np.float64(0.7962746236655202), 'f1_weighted avg': np.float64(0.7864050763180664), 'precision_negative': np.float64(0.8447803432112737), 'recall_negative': np.float64(0.8654320987654321), 'f1_negative': np.float64(0.8549231495314362), 'precision_non-hit': np.float64(0.76120148204855), 'recall_non-hit': np.float64(0.8419753086419753), 'f1_non-hit': np.float64(0.7995255607420001), 'precision_positive': np.float64(0.7150175706646295), 'recall_positive': np.float64(0.35537098560354374), 'f1_positive': np.float64(0.4730154656933013), 'roc_auc_weighted': np.float64(0.8972475970177914), 'roc_auc_macro': np.float64(0.8752386335139972), 'pr_auc_weighted': np.float64(0.8274671536705294), 'pr_auc_macro': np.float64(0.744518186793574)}
# Confusion Matrix:
#  [[701 102   7]
#  [105 682  23]
#  [ 24 112  75]]
#
# --- Run 10/10 ---
# Metrics: {'accuracy': np.float64(0.7973660308810173), 'precision_macro avg': np.float64(0.7828387611716241), 'recall_macro avg': np.float64(0.68724006398425), 'f1_macro avg': np.float64(0.7101483678758088), 'precision_weighted avg': np.float64(0.7959018917961872), 'recall_weighted avg': np.float64(0.7973660308810173), 'f1_weighted avg': np.float64(0.7871439835771262), 'precision_negative': np.float64(0.8464152220877648), 'recall_negative': np.float64(0.8641975308641975), 'f1_negative': np.float64(0.8551443862402497), 'precision_non-hit': np.float64(0.7592527758678242), 'recall_non-hit': np.float64(0.8469135802469137), 'f1_non-hit': np.float64(0.8005191524361202), 'precision_positive': np.float64(0.7428482855592831), 'recall_positive': np.float64(0.35060908084163894), 'f1_positive': np.float64(0.47478156495105656), 'roc_auc_weighted': np.float64(0.8926349622477856), 'roc_auc_macro': np.float64(0.8716552073562678), 'pr_auc_weighted': np.float64(0.8207069519050837), 'pr_auc_macro': np.float64(0.7416677717226078)}
# Confusion Matrix:
#  [[700 105   5]
#  [103 686  21]
#  [ 24 113  74]]
# === Mean metrics ===
# accuracy                  0.790107
# precision_macro avg       0.764363
# recall_macro avg          0.678589
# f1_macro avg              0.698595
# precision_weighted avg    0.787062
# recall_weighted avg       0.790107
# f1_weighted avg           0.779664
# precision_negative        0.845723
# recall_negative           0.855802
# f1_negative               0.850423
# precision_non-hit         0.752401
# recall_non-hit            0.842222
# f1_non-hit                0.794541
# precision_positive        0.694964
# recall_positive           0.337741
# f1_positive               0.450822
# roc_auc_weighted          0.892093
# roc_auc_macro             0.871817
# pr_auc_weighted           0.820025
# pr_auc_macro              0.740484
# dtype: float64
#
# === Std metrics ===
# accuracy                  0.007291
# precision_macro avg       0.015198
# recall_macro avg          0.010649
# f1_macro avg              0.012443
# precision_weighted avg    0.008398
# recall_weighted avg       0.007291
# f1_weighted avg           0.007914
# precision_negative        0.004666
# recall_negative           0.007003
# f1_negative               0.004667
# precision_non-hit         0.007446
# recall_non-hit            0.009873
# f1_non-hit                0.007535
# precision_positive        0.037800
# recall_positive           0.022028
# f1_positive               0.026829
# roc_auc_weighted          0.004111
# roc_auc_macro             0.003858
# pr_auc_weighted           0.007552
# pr_auc_macro              0.008903
# dtype: float64
#
# === Mean confusion matrix ===
# [[693.2 109.    7.8]
#  [103.2 682.2  24.6]
#  [ 23.9 115.8  71.3]]
#
# === Std confusion matrix ===
# [[5.38144962 4.44971909 2.27156334]
#  [4.48998886 7.5868307  4.24735212]
#  [1.5132746  4.14246304 4.40567815]]

# %%
def summarize_results(metrics_list, cms, class_names):
    """
    Summarize metrics (global + class-wise) and confusion matrices across runs.

    Parameters
    ----------
    metrics_list : list of dict
        Each element is the metrics dict returned from train_test_once.
    cms : list of np.ndarray
        Confusion matrices (one per run).
    class_names : list
        Names of classes for the confusion matrix.
    """

    # === Metrics summary ===
    metrics_keys = metrics_list[0].keys()
    summary = {}
    for key in metrics_keys:
        values = np.array([m[key] for m in metrics_list])
        summary[key] = (np.mean(values), np.std(values))

    print("\n=== Metrics Summary (mean ± std) ===")

    # Global averages
    for k in ["accuracy", "roc_auc_weighted", "roc_auc_macro",
              "pr_auc_weighted", "pr_auc_macro"]:
        mean, std = summary[k]
        print(f"{k:20s}: {mean:.3f} ± {std:.3f}")

    # Macro/weighted averages
    for k in ["precision_macro avg", "recall_macro avg", "f1_macro avg",
              "precision_weighted avg", "recall_weighted avg", "f1_weighted avg"]:
        if k in summary:
            mean, std = summary[k]
            print(f"{k:20s}: {mean:.3f} ± {std:.3f}")

    # Class-wise metrics
    print("\n=== Class-wise Metrics (mean ± std) ===")
    for cname in class_names:
        for metric in ["precision", "recall", "f1"]:
            key = f"{metric}_{cname}"
            if key in summary:
                mean, std = summary[key]
                print(f"{cname:10s} {metric:10s}: {mean:.3f} ± {std:.3f}")

    # === Confusion Matrix summary ===
    cm_array = np.stack(cms)  # shape (n_runs, n_classes, n_classes)
    cm_mean = np.mean(cm_array, axis=0)
    cm_std = np.std(cm_array, axis=0)

    # Combined annotated version
    combined = np.empty(cm_mean.shape, dtype=object)
    for i in range(cm_mean.shape[0]):
        for j in range(cm_mean.shape[1]):
            mean_val = int(round(cm_mean[i, j]))   # integer
            std_val = int(cm_std[i, j])       # 1 decimal
            combined[i, j] = f"{mean_val}±{std_val}"

    #for i in range(cm_mean.shape[0]):
    #    for j in range(cm_mean.shape[1]):
    #        combined[i, j] = f"{cm_mean[i,j]:.1f}±{cm_std[i,j]:.1f}"

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm_mean, annot=combined, fmt="", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names)
    #plt.title("Confusion Matrix (mean ± std)")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

    return summary, cm_mean, cm_std

# %%
metrics_summary, cm_mean, cm_std = summarize_results(all_metrics, all_cms,
                                                     class_names=le.classes_)
# Out:
# === Metrics Summary (mean ± std) ===
# accuracy            : 0.790 ± 0.007
# roc_auc_weighted    : 0.892 ± 0.004
# roc_auc_macro       : 0.872 ± 0.004
# pr_auc_weighted     : 0.820 ± 0.007
# pr_auc_macro        : 0.740 ± 0.008
# precision_macro avg : 0.764 ± 0.014
# recall_macro avg    : 0.679 ± 0.010
# f1_macro avg        : 0.699 ± 0.012
# precision_weighted avg: 0.787 ± 0.008
# recall_weighted avg : 0.790 ± 0.007
# f1_weighted avg     : 0.780 ± 0.008
#
# === Class-wise Metrics (mean ± std) ===
# negative   precision : 0.846 ± 0.004
# negative   recall    : 0.856 ± 0.007
# negative   f1        : 0.850 ± 0.004
# non-hit    precision : 0.752 ± 0.007
# non-hit    recall    : 0.842 ± 0.009
# non-hit    f1        : 0.795 ± 0.007
# positive   precision : 0.695 ± 0.036
# positive   recall    : 0.338 ± 0.021
# positive   f1        : 0.451 ± 0.025

# %% [markdown]
# ## Hyperparameter Tunning

# %% [markdown]
# ### Random Search

# %%
params = {
    "n_estimators": [50, 100, 200, 300, 500, 700, 1000, 1500, 2000],  # number of boosting rounds
    "max_depth": [3, 6, 9, 12],                         
    "learning_rate": [0.01, 0.1, 0.2],              
    "subsample": [0.7, 0.85, 1.0],                  # defines the fraction of training instances to be used for each tree
    "colsample_bytree": [0.7, 0.85, 1.0],           # feature sampling
    "min_child_weight": [1, 3, 5],                  # min sum of instance weight in child
    "reg_alpha": [0, 0.01, 0.1, 1, 10, 50],         # L1 regularization
    "reg_lambda": [0.5, 0.7, 1, 1.3],               # L2 regularization
}

xgb = XGBClassifier(
    objective="multi:softprob", 
    num_class=len(le.classes_), 
    random_state=1
)

# Stratified K-Fold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=params,
    n_iter=500,               
    scoring="f1_weighted",    
    cv=cv,
    verbose=2,
    random_state=1,
    n_jobs=-1
)

start = time.time()
random_search.fit(X, y)
end = time.time()

#Best parameters and score from tuning 
print("Best parameters: ", random_search.best_params_)
print("Best score (f1_weighted): ", random_search.best_score_)
print(f"\nTotal tuning time: {end - start:.2f} seconds")
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=1, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=1500, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=1, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=1, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=1, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=1, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   0.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   6.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   6.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   6.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=700, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=2000, reg_alpha=1, reg_lambda=1.3, subsample=1.0; total time=  16.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=2000, reg_alpha=1, reg_lambda=1.3, subsample=1.0; total time=  16.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   6.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=2000, reg_alpha=1, reg_lambda=1.3, subsample=1.0; total time=  17.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=2000, reg_alpha=1, reg_lambda=1.3, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=12, min_child_weight=5, n_estimators=2000, reg_alpha=1, reg_lambda=1.3, subsample=1.0; total time=  16.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   6.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=700, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=10, reg_lambda=0.7, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=700, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=700, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=700, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   3.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   3.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0.01, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   5.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   5.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   5.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=  18.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=  19.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=  19.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=  19.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=1000, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=  19.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=500, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=500, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=500, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=500, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=500, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=0.7; total time=   2.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=0.7; total time=   2.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=0.7; total time=   2.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   4.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   4.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   4.9s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   4.9s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   6.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   1.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   1.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.5, subsample=0.85; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   1.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.5, subsample=0.85; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   1.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.5, subsample=0.85; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.5, subsample=0.85; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.5, subsample=0.85; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   1.9s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=1.3, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=1.3, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=1.3, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   6.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=1.3, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   6.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=1.3, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=700, reg_alpha=50, reg_lambda=1.3, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=700, reg_alpha=50, reg_lambda=1.3, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=700, reg_alpha=50, reg_lambda=1.3, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=1, reg_lambda=0.7, subsample=0.85; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=1, reg_lambda=0.7, subsample=0.85; total time=   5.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=700, reg_alpha=50, reg_lambda=1.3, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=1, reg_lambda=0.7, subsample=0.85; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=1, reg_lambda=0.7, subsample=0.85; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=700, reg_alpha=50, reg_lambda=1.3, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=700, reg_alpha=1, reg_lambda=0.7, subsample=0.85; total time=   5.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=0.7, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=50, reg_alpha=50, reg_lambda=0.7, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=1, subsample=0.85; total time=   0.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=1, subsample=0.85; total time=   0.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=1, subsample=0.85; total time=   0.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=1, subsample=0.85; total time=   0.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=1, subsample=0.85; total time=   0.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.5, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=0.85; total time=   6.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=0.85; total time=   6.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=0.85; total time=   6.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=0.85; total time=   6.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=0.85; total time=   6.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   7.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   7.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, reg_alpha=10, reg_lambda=0.5, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, reg_alpha=10, reg_lambda=0.5, subsample=0.7; total time=   2.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, reg_alpha=10, reg_lambda=0.5, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, reg_alpha=10, reg_lambda=0.5, subsample=0.7; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, reg_alpha=10, reg_lambda=0.5, subsample=0.7; total time=   2.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1500, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=0.85; total time=   9.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=0.85; total time=   9.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=0.85; total time=  10.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=0.85; total time=  10.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.01, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.01, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.01, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.01, reg_lambda=0.7, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.01, reg_lambda=0.7, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1.3, subsample=0.85; total time=   9.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=1000, reg_alpha=0.01, reg_lambda=0.5, subsample=0.85; total time=  10.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1.3, subsample=0.85; total time=   9.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1.3, subsample=0.85; total time=   9.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1.3, subsample=0.85; total time=   9.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1.3, subsample=0.85; total time=   9.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.85; total time=   9.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.85; total time=   9.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.85; total time=   9.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=50, reg_lambda=0.7, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.85; total time=   9.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.85; total time=   9.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=10, reg_lambda=1.3, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  12.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.1, reg_lambda=1.3, subsample=1.0; total time=   8.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.1, reg_lambda=1.3, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.1, reg_lambda=1.3, subsample=1.0; total time=   7.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  11.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  12.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=1500, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.1, reg_lambda=1.3, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=1000, reg_alpha=0.1, reg_lambda=1.3, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=700, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   9.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=700, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=700, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   8.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=700, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   9.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=12, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   1.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   1.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=700, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   9.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.85; total time=   1.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=1.3, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=1.3, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=1.3, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=1.3, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=1.3, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0.7, subsample=0.7; total time=   2.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=700, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   4.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   5.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.5, subsample=1.0; total time=   5.3s
# ...
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.5, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1.3, subsample=0.7; total time=  10.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1.3, subsample=0.7; total time=  10.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1.3, subsample=0.7; total time=  10.3s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1.3, subsample=0.7; total time=  10.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   5.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1500, reg_alpha=1, reg_lambda=1.3, subsample=0.7; total time=  10.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   4.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   4.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, reg_alpha=10, reg_lambda=0.7, subsample=0.85; total time=   4.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=50, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   2.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   1.9s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   1.9s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=0.7, subsample=1.0; total time=   7.5s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   2.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   1.9s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=  31.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=  31.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=  30.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=  30.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=  31.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.85, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0.7, subsample=1.0; total time=   4.1s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=500, reg_alpha=10, reg_lambda=1.3, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  23.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  23.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=500, reg_alpha=10, reg_lambda=1.3, subsample=1.0; total time=   7.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  22.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=500, reg_alpha=10, reg_lambda=1.3, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=500, reg_alpha=10, reg_lambda=1.3, subsample=1.0; total time=  10.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  26.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1.3, subsample=0.85; total time=  10.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1.3, subsample=0.85; total time=  10.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1.3, subsample=0.85; total time=  10.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1.3, subsample=0.85; total time=  10.0s
# [CV] END colsample_bytree=0.85, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=500, reg_alpha=10, reg_lambda=1.3, subsample=1.0; total time=  11.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=12, min_child_weight=3, n_estimators=700, reg_alpha=0.1, reg_lambda=0.7, subsample=1.0; total time=  26.4s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.85, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=10, reg_lambda=1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1.3, subsample=0.85; total time=   6.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   5.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   5.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   5.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=0.85; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=0.85; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=0.85; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=6, min_child_weight=5, n_estimators=2000, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   6.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=0.85; total time=   5.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.7, subsample=0.85; total time=   5.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.5, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.5, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   5.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   5.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   5.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   5.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1500, reg_alpha=50, reg_lambda=0.7, subsample=0.85; total time=   5.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=50, reg_lambda=0.5, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.5, subsample=0.85; total time=   1.7s
# Best parameters:  {'subsample': 0.85, 'reg_lambda': 1.3, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 3, 'max_depth': 12, 'learning_rate': 0.01, 'colsample_bytree': 0.85}
# Best score (f1_weighted):  0.7215152396766773
#
# Total tuning time: 1791.73 seconds

# %% [markdown]
# ### Bayes Optimization

# %%
params_bayes = {
    'n_estimators': Integer(50, 2000),
    'max_depth': Integer(3, 9),
    'learning_rate': Real(0.01, 0.2, prior='log-uniform'),  
    'subsample': Real(0.7, 1.0),
    'colsample_bytree': Real(0.7, 1.0),
    'min_child_weight': Integer(1, 10),
    'reg_alpha': Real(0.0001, 50, prior='log-uniform'),  # L1 
    'reg_lambda': Real(0.0001, 2, prior='log-uniform'),    # L2 
}

xgb = XGBClassifier(
    objective="multi:softprob", 
    num_class=len(le.classes_), 
    random_state=1
)

# Stratified K-Fold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

bayes_search = BayesSearchCV(
    estimator=xgb,
    search_spaces=params_bayes,
    n_iter=100,               
    scoring="f1_weighted",    
    cv=cv,
    verbose=2,
    random_state=1,
    n_jobs=-1
)

start = time.time()
bayes_search.fit(X, y)
end = time.time()

#Best parameters and score from tuning
print("Best parameters: ", bayes_search.best_params_)
print("Best score (f1_weighted): ", bayes_search.best_score_)
print(f"\nTotal tuning time: {end - start:.2f} seconds")
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9107934977333076, learning_rate=0.012028480054085435, max_depth=5, min_child_weight=2, n_estimators=1012, reg_alpha=11.640167211727219, reg_lambda=0.00017846585664349146, subsample=0.7767084453482135; total time=   4.7s
# [CV] END colsample_bytree=0.9107934977333076, learning_rate=0.012028480054085435, max_depth=5, min_child_weight=2, n_estimators=1012, reg_alpha=11.640167211727219, reg_lambda=0.00017846585664349146, subsample=0.7767084453482135; total time=   4.8s
# [CV] END colsample_bytree=0.9107934977333076, learning_rate=0.012028480054085435, max_depth=5, min_child_weight=2, n_estimators=1012, reg_alpha=11.640167211727219, reg_lambda=0.00017846585664349146, subsample=0.7767084453482135; total time=   4.8s
# [CV] END colsample_bytree=0.9107934977333076, learning_rate=0.012028480054085435, max_depth=5, min_child_weight=2, n_estimators=1012, reg_alpha=11.640167211727219, reg_lambda=0.00017846585664349146, subsample=0.7767084453482135; total time=   4.8s
# [CV] END colsample_bytree=0.9107934977333076, learning_rate=0.012028480054085435, max_depth=5, min_child_weight=2, n_estimators=1012, reg_alpha=11.640167211727219, reg_lambda=0.00017846585664349146, subsample=0.7767084453482135; total time=   4.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9050672319622874, learning_rate=0.02724790723366069, max_depth=3, min_child_weight=5, n_estimators=837, reg_alpha=1.7944324534657004, reg_lambda=0.0001545042053965987, subsample=0.8104942368686818; total time=   2.2s
# [CV] END colsample_bytree=0.9050672319622874, learning_rate=0.02724790723366069, max_depth=3, min_child_weight=5, n_estimators=837, reg_alpha=1.7944324534657004, reg_lambda=0.0001545042053965987, subsample=0.8104942368686818; total time=   2.2s
# [CV] END colsample_bytree=0.9050672319622874, learning_rate=0.02724790723366069, max_depth=3, min_child_weight=5, n_estimators=837, reg_alpha=1.7944324534657004, reg_lambda=0.0001545042053965987, subsample=0.8104942368686818; total time=   2.3s
# [CV] END colsample_bytree=0.9050672319622874, learning_rate=0.02724790723366069, max_depth=3, min_child_weight=5, n_estimators=837, reg_alpha=1.7944324534657004, reg_lambda=0.0001545042053965987, subsample=0.8104942368686818; total time=   2.3s
# [CV] END colsample_bytree=0.9050672319622874, learning_rate=0.02724790723366069, max_depth=3, min_child_weight=5, n_estimators=837, reg_alpha=1.7944324534657004, reg_lambda=0.0001545042053965987, subsample=0.8104942368686818; total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9491197036621863, learning_rate=0.010411123976594935, max_depth=8, min_child_weight=4, n_estimators=924, reg_alpha=0.8530316109552624, reg_lambda=0.08999226083875796, subsample=0.8058625936905032; total time=   8.6s
# [CV] END colsample_bytree=0.9491197036621863, learning_rate=0.010411123976594935, max_depth=8, min_child_weight=4, n_estimators=924, reg_alpha=0.8530316109552624, reg_lambda=0.08999226083875796, subsample=0.8058625936905032; total time=   8.7s
# [CV] END colsample_bytree=0.9491197036621863, learning_rate=0.010411123976594935, max_depth=8, min_child_weight=4, n_estimators=924, reg_alpha=0.8530316109552624, reg_lambda=0.08999226083875796, subsample=0.8058625936905032; total time=   8.8s
# [CV] END colsample_bytree=0.9491197036621863, learning_rate=0.010411123976594935, max_depth=8, min_child_weight=4, n_estimators=924, reg_alpha=0.8530316109552624, reg_lambda=0.08999226083875796, subsample=0.8058625936905032; total time=   8.9s
# [CV] END colsample_bytree=0.9491197036621863, learning_rate=0.010411123976594935, max_depth=8, min_child_weight=4, n_estimators=924, reg_alpha=0.8530316109552624, reg_lambda=0.08999226083875796, subsample=0.8058625936905032; total time=   8.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9110320125564719, learning_rate=0.03431379975326643, max_depth=4, min_child_weight=5, n_estimators=864, reg_alpha=9.491251279040064, reg_lambda=1.8540591553392771, subsample=0.8886608972539971; total time=   2.5s
# [CV] END colsample_bytree=0.9110320125564719, learning_rate=0.03431379975326643, max_depth=4, min_child_weight=5, n_estimators=864, reg_alpha=9.491251279040064, reg_lambda=1.8540591553392771, subsample=0.8886608972539971; total time=   2.6s
# [CV] END colsample_bytree=0.9110320125564719, learning_rate=0.03431379975326643, max_depth=4, min_child_weight=5, n_estimators=864, reg_alpha=9.491251279040064, reg_lambda=1.8540591553392771, subsample=0.8886608972539971; total time=   2.6s
# [CV] END colsample_bytree=0.9110320125564719, learning_rate=0.03431379975326643, max_depth=4, min_child_weight=5, n_estimators=864, reg_alpha=9.491251279040064, reg_lambda=1.8540591553392771, subsample=0.8886608972539971; total time=   2.6s
# [CV] END colsample_bytree=0.9110320125564719, learning_rate=0.03431379975326643, max_depth=4, min_child_weight=5, n_estimators=864, reg_alpha=9.491251279040064, reg_lambda=1.8540591553392771, subsample=0.8886608972539971; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.963305539576188, learning_rate=0.029358638187649763, max_depth=3, min_child_weight=6, n_estimators=968, reg_alpha=0.03814919103183551, reg_lambda=0.14751118840804398, subsample=0.8516696346487376; total time=   2.3s
# [CV] END colsample_bytree=0.963305539576188, learning_rate=0.029358638187649763, max_depth=3, min_child_weight=6, n_estimators=968, reg_alpha=0.03814919103183551, reg_lambda=0.14751118840804398, subsample=0.8516696346487376; total time=   2.3s
# [CV] END colsample_bytree=0.963305539576188, learning_rate=0.029358638187649763, max_depth=3, min_child_weight=6, n_estimators=968, reg_alpha=0.03814919103183551, reg_lambda=0.14751118840804398, subsample=0.8516696346487376; total time=   2.4s
# [CV] END colsample_bytree=0.963305539576188, learning_rate=0.029358638187649763, max_depth=3, min_child_weight=6, n_estimators=968, reg_alpha=0.03814919103183551, reg_lambda=0.14751118840804398, subsample=0.8516696346487376; total time=   2.4s
# [CV] END colsample_bytree=0.963305539576188, learning_rate=0.029358638187649763, max_depth=3, min_child_weight=6, n_estimators=968, reg_alpha=0.03814919103183551, reg_lambda=0.14751118840804398, subsample=0.8516696346487376; total time=   2.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9902697389285025, learning_rate=0.03642007317273981, max_depth=7, min_child_weight=3, n_estimators=1274, reg_alpha=0.00011296493837202772, reg_lambda=0.08249242624163178, subsample=0.7919999151781771; total time=   6.7s
# [CV] END colsample_bytree=0.9902697389285025, learning_rate=0.03642007317273981, max_depth=7, min_child_weight=3, n_estimators=1274, reg_alpha=0.00011296493837202772, reg_lambda=0.08249242624163178, subsample=0.7919999151781771; total time=   6.7s
# [CV] END colsample_bytree=0.9902697389285025, learning_rate=0.03642007317273981, max_depth=7, min_child_weight=3, n_estimators=1274, reg_alpha=0.00011296493837202772, reg_lambda=0.08249242624163178, subsample=0.7919999151781771; total time=   6.9s
# [CV] END colsample_bytree=0.9902697389285025, learning_rate=0.03642007317273981, max_depth=7, min_child_weight=3, n_estimators=1274, reg_alpha=0.00011296493837202772, reg_lambda=0.08249242624163178, subsample=0.7919999151781771; total time=   6.8s
# [CV] END colsample_bytree=0.9902697389285025, learning_rate=0.03642007317273981, max_depth=7, min_child_weight=3, n_estimators=1274, reg_alpha=0.00011296493837202772, reg_lambda=0.08249242624163178, subsample=0.7919999151781771; total time=   6.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8949153784611096, learning_rate=0.013360858727399711, max_depth=7, min_child_weight=4, n_estimators=478, reg_alpha=4.507141018940401, reg_lambda=0.026227781597385716, subsample=0.840917372537952; total time=   4.4s
# [CV] END colsample_bytree=0.8949153784611096, learning_rate=0.013360858727399711, max_depth=7, min_child_weight=4, n_estimators=478, reg_alpha=4.507141018940401, reg_lambda=0.026227781597385716, subsample=0.840917372537952; total time=   4.4s
# [CV] END colsample_bytree=0.8949153784611096, learning_rate=0.013360858727399711, max_depth=7, min_child_weight=4, n_estimators=478, reg_alpha=4.507141018940401, reg_lambda=0.026227781597385716, subsample=0.840917372537952; total time=   4.5s
# [CV] END colsample_bytree=0.8949153784611096, learning_rate=0.013360858727399711, max_depth=7, min_child_weight=4, n_estimators=478, reg_alpha=4.507141018940401, reg_lambda=0.026227781597385716, subsample=0.840917372537952; total time=   4.5s
# [CV] END colsample_bytree=0.8949153784611096, learning_rate=0.013360858727399711, max_depth=7, min_child_weight=4, n_estimators=478, reg_alpha=4.507141018940401, reg_lambda=0.026227781597385716, subsample=0.840917372537952; total time=   4.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7948436358956348, learning_rate=0.09147539226393192, max_depth=8, min_child_weight=6, n_estimators=1291, reg_alpha=0.000161534745837024, reg_lambda=0.013148935980730699, subsample=0.7016536803082958; total time=   3.4s
# [CV] END colsample_bytree=0.7948436358956348, learning_rate=0.09147539226393192, max_depth=8, min_child_weight=6, n_estimators=1291, reg_alpha=0.000161534745837024, reg_lambda=0.013148935980730699, subsample=0.7016536803082958; total time=   3.5s
# [CV] END colsample_bytree=0.7948436358956348, learning_rate=0.09147539226393192, max_depth=8, min_child_weight=6, n_estimators=1291, reg_alpha=0.000161534745837024, reg_lambda=0.013148935980730699, subsample=0.7016536803082958; total time=   3.5s
# [CV] END colsample_bytree=0.7948436358956348, learning_rate=0.09147539226393192, max_depth=8, min_child_weight=6, n_estimators=1291, reg_alpha=0.000161534745837024, reg_lambda=0.013148935980730699, subsample=0.7016536803082958; total time=   3.5s
# [CV] END colsample_bytree=0.7948436358956348, learning_rate=0.09147539226393192, max_depth=8, min_child_weight=6, n_estimators=1291, reg_alpha=0.000161534745837024, reg_lambda=0.013148935980730699, subsample=0.7016536803082958; total time=   3.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8342271858482788, learning_rate=0.04727716018290433, max_depth=8, min_child_weight=7, n_estimators=871, reg_alpha=0.04890363924558207, reg_lambda=0.0027333670381147813, subsample=0.9741099380065688; total time=   4.1s
# [CV] END colsample_bytree=0.8342271858482788, learning_rate=0.04727716018290433, max_depth=8, min_child_weight=7, n_estimators=871, reg_alpha=0.04890363924558207, reg_lambda=0.0027333670381147813, subsample=0.9741099380065688; total time=   4.2s
# [CV] END colsample_bytree=0.8342271858482788, learning_rate=0.04727716018290433, max_depth=8, min_child_weight=7, n_estimators=871, reg_alpha=0.04890363924558207, reg_lambda=0.0027333670381147813, subsample=0.9741099380065688; total time=   4.2s
# [CV] END colsample_bytree=0.8342271858482788, learning_rate=0.04727716018290433, max_depth=8, min_child_weight=7, n_estimators=871, reg_alpha=0.04890363924558207, reg_lambda=0.0027333670381147813, subsample=0.9741099380065688; total time=   4.2s
# [CV] END colsample_bytree=0.8342271858482788, learning_rate=0.04727716018290433, max_depth=8, min_child_weight=7, n_estimators=871, reg_alpha=0.04890363924558207, reg_lambda=0.0027333670381147813, subsample=0.9741099380065688; total time=   4.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7349433286673693, learning_rate=0.07518772747733099, max_depth=7, min_child_weight=8, n_estimators=1723, reg_alpha=0.010192324673584342, reg_lambda=0.14273340220138964, subsample=0.975661231155694; total time=   4.4s
# [CV] END colsample_bytree=0.7349433286673693, learning_rate=0.07518772747733099, max_depth=7, min_child_weight=8, n_estimators=1723, reg_alpha=0.010192324673584342, reg_lambda=0.14273340220138964, subsample=0.975661231155694; total time=   4.5s
# [CV] END colsample_bytree=0.7349433286673693, learning_rate=0.07518772747733099, max_depth=7, min_child_weight=8, n_estimators=1723, reg_alpha=0.010192324673584342, reg_lambda=0.14273340220138964, subsample=0.975661231155694; total time=   4.5s
# [CV] END colsample_bytree=0.7349433286673693, learning_rate=0.07518772747733099, max_depth=7, min_child_weight=8, n_estimators=1723, reg_alpha=0.010192324673584342, reg_lambda=0.14273340220138964, subsample=0.975661231155694; total time=   4.5s
# [CV] END colsample_bytree=0.7349433286673693, learning_rate=0.07518772747733099, max_depth=7, min_child_weight=8, n_estimators=1723, reg_alpha=0.010192324673584342, reg_lambda=0.14273340220138964, subsample=0.975661231155694; total time=   4.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=557, reg_alpha=3.682714214540409, reg_lambda=0.02407441120509799, subsample=0.9771033009042625; total time=   8.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=557, reg_alpha=3.682714214540409, reg_lambda=0.02407441120509799, subsample=0.9771033009042625; total time=   8.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=557, reg_alpha=3.682714214540409, reg_lambda=0.02407441120509799, subsample=0.9771033009042625; total time=   8.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=557, reg_alpha=3.682714214540409, reg_lambda=0.02407441120509799, subsample=0.9771033009042625; total time=   9.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=557, reg_alpha=3.682714214540409, reg_lambda=0.02407441120509799, subsample=0.9771033009042625; total time=   9.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9935465944231674, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=2000, reg_alpha=0.3090444459331704, reg_lambda=0.0008072182553588061, subsample=0.8141521071983121; total time=  13.0s
# [CV] END colsample_bytree=0.9935465944231674, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=2000, reg_alpha=0.3090444459331704, reg_lambda=0.0008072182553588061, subsample=0.8141521071983121; total time=  13.2s
# [CV] END colsample_bytree=0.9935465944231674, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=2000, reg_alpha=0.3090444459331704, reg_lambda=0.0008072182553588061, subsample=0.8141521071983121; total time=  13.2s
# [CV] END colsample_bytree=0.9935465944231674, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=2000, reg_alpha=0.3090444459331704, reg_lambda=0.0008072182553588061, subsample=0.8141521071983121; total time=  13.3s
# [CV] END colsample_bytree=0.9935465944231674, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=2000, reg_alpha=0.3090444459331704, reg_lambda=0.0008072182553588061, subsample=0.8141521071983121; total time=  13.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.04687387606974529, max_depth=9, min_child_weight=10, n_estimators=605, reg_alpha=0.5444110925145534, reg_lambda=2.0, subsample=1.0; total time=   3.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.04687387606974529, max_depth=9, min_child_weight=10, n_estimators=605, reg_alpha=0.5444110925145534, reg_lambda=2.0, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.04687387606974529, max_depth=9, min_child_weight=10, n_estimators=605, reg_alpha=0.5444110925145534, reg_lambda=2.0, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.04687387606974529, max_depth=9, min_child_weight=10, n_estimators=605, reg_alpha=0.5444110925145534, reg_lambda=2.0, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.04687387606974529, max_depth=9, min_child_weight=10, n_estimators=605, reg_alpha=0.5444110925145534, reg_lambda=2.0, subsample=1.0; total time=   3.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.05956100505708381, max_depth=9, min_child_weight=1, n_estimators=421, reg_alpha=0.004348403820590541, reg_lambda=0.0001, subsample=0.9950885384948137; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05956100505708381, max_depth=9, min_child_weight=1, n_estimators=421, reg_alpha=0.004348403820590541, reg_lambda=0.0001, subsample=0.9950885384948137; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05956100505708381, max_depth=9, min_child_weight=1, n_estimators=421, reg_alpha=0.004348403820590541, reg_lambda=0.0001, subsample=0.9950885384948137; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05956100505708381, max_depth=9, min_child_weight=1, n_estimators=421, reg_alpha=0.004348403820590541, reg_lambda=0.0001, subsample=0.9950885384948137; total time=   4.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05956100505708381, max_depth=9, min_child_weight=1, n_estimators=421, reg_alpha=0.004348403820590541, reg_lambda=0.0001, subsample=0.9950885384948137; total time=   4.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9843588157444358, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1756, reg_alpha=0.0009911086880587555, reg_lambda=2.0, subsample=0.9725272723133935; total time=   4.7s
# [CV] END colsample_bytree=0.9843588157444358, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1756, reg_alpha=0.0009911086880587555, reg_lambda=2.0, subsample=0.9725272723133935; total time=   4.7s
# [CV] END colsample_bytree=0.9843588157444358, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1756, reg_alpha=0.0009911086880587555, reg_lambda=2.0, subsample=0.9725272723133935; total time=   4.8s
# [CV] END colsample_bytree=0.9843588157444358, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1756, reg_alpha=0.0009911086880587555, reg_lambda=2.0, subsample=0.9725272723133935; total time=   4.8s
# [CV] END colsample_bytree=0.9843588157444358, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=1756, reg_alpha=0.0009911086880587555, reg_lambda=2.0, subsample=0.9725272723133935; total time=   4.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9039034323521271, learning_rate=0.11343820219236743, max_depth=9, min_child_weight=1, n_estimators=1544, reg_alpha=0.014561252462061641, reg_lambda=0.0001, subsample=0.706557495779687; total time=   6.6s
# [CV] END colsample_bytree=0.9039034323521271, learning_rate=0.11343820219236743, max_depth=9, min_child_weight=1, n_estimators=1544, reg_alpha=0.014561252462061641, reg_lambda=0.0001, subsample=0.706557495779687; total time=   7.5s
# [CV] END colsample_bytree=0.9039034323521271, learning_rate=0.11343820219236743, max_depth=9, min_child_weight=1, n_estimators=1544, reg_alpha=0.014561252462061641, reg_lambda=0.0001, subsample=0.706557495779687; total time=   7.6s
# [CV] END colsample_bytree=0.9039034323521271, learning_rate=0.11343820219236743, max_depth=9, min_child_weight=1, n_estimators=1544, reg_alpha=0.014561252462061641, reg_lambda=0.0001, subsample=0.706557495779687; total time=   7.7s
# [CV] END colsample_bytree=0.9039034323521271, learning_rate=0.11343820219236743, max_depth=9, min_child_weight=1, n_estimators=1544, reg_alpha=0.014561252462061641, reg_lambda=0.0001, subsample=0.706557495779687; total time=   8.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, min_child_weight=9, n_estimators=50, reg_alpha=0.0015696144140277006, reg_lambda=0.09581180258675434, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, min_child_weight=9, n_estimators=50, reg_alpha=0.0015696144140277006, reg_lambda=0.09581180258675434, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, min_child_weight=9, n_estimators=50, reg_alpha=0.0015696144140277006, reg_lambda=0.09581180258675434, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, min_child_weight=9, n_estimators=50, reg_alpha=0.0015696144140277006, reg_lambda=0.09581180258675434, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=7, min_child_weight=9, n_estimators=50, reg_alpha=0.0015696144140277006, reg_lambda=0.09581180258675434, subsample=1.0; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8057767275831286, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=12.264373316400317, reg_lambda=0.33500488876998163, subsample=0.8828108103192464; total time=   9.4s
# [CV] END colsample_bytree=0.8057767275831286, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=12.264373316400317, reg_lambda=0.33500488876998163, subsample=0.8828108103192464; total time=   9.4s
# [CV] END colsample_bytree=0.8057767275831286, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=12.264373316400317, reg_lambda=0.33500488876998163, subsample=0.8828108103192464; total time=   9.5s
# [CV] END colsample_bytree=0.8057767275831286, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=12.264373316400317, reg_lambda=0.33500488876998163, subsample=0.8828108103192464; total time=   9.7s
# [CV] END colsample_bytree=0.8057767275831286, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=12.264373316400317, reg_lambda=0.33500488876998163, subsample=0.8828108103192464; total time=   9.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7164946963912593, learning_rate=0.2, max_depth=9, min_child_weight=8, n_estimators=771, reg_alpha=28.444024901897873, reg_lambda=0.9710662597712095, subsample=0.7809185431995576; total time=   0.6s
# [CV] END colsample_bytree=0.7164946963912593, learning_rate=0.2, max_depth=9, min_child_weight=8, n_estimators=771, reg_alpha=28.444024901897873, reg_lambda=0.9710662597712095, subsample=0.7809185431995576; total time=   0.6s
# [CV] END colsample_bytree=0.7164946963912593, learning_rate=0.2, max_depth=9, min_child_weight=8, n_estimators=771, reg_alpha=28.444024901897873, reg_lambda=0.9710662597712095, subsample=0.7809185431995576; total time=   0.7s
# [CV] END colsample_bytree=0.7164946963912593, learning_rate=0.2, max_depth=9, min_child_weight=8, n_estimators=771, reg_alpha=28.444024901897873, reg_lambda=0.9710662597712095, subsample=0.7809185431995576; total time=   0.6s
# [CV] END colsample_bytree=0.7164946963912593, learning_rate=0.2, max_depth=9, min_child_weight=8, n_estimators=771, reg_alpha=28.444024901897873, reg_lambda=0.9710662597712095, subsample=0.7809185431995576; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9903566365429539, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   9.0s
# [CV] END colsample_bytree=0.9903566365429539, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   9.7s
# [CV] END colsample_bytree=0.9903566365429539, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=  10.4s
# [CV] END colsample_bytree=0.9903566365429539, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=0.9903566365429539, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=  11.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7544909158606867, learning_rate=0.018670388655912553, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.005362835348980009, reg_lambda=0.0001, subsample=0.9531460560353123; total time=  14.3s
# [CV] END colsample_bytree=0.7544909158606867, learning_rate=0.018670388655912553, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.005362835348980009, reg_lambda=0.0001, subsample=0.9531460560353123; total time=  14.5s
# [CV] END colsample_bytree=0.7544909158606867, learning_rate=0.018670388655912553, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.005362835348980009, reg_lambda=0.0001, subsample=0.9531460560353123; total time=  14.6s
# [CV] END colsample_bytree=0.7544909158606867, learning_rate=0.018670388655912553, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.005362835348980009, reg_lambda=0.0001, subsample=0.9531460560353123; total time=  14.6s
# [CV] END colsample_bytree=0.7544909158606867, learning_rate=0.018670388655912553, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.005362835348980009, reg_lambda=0.0001, subsample=0.9531460560353123; total time=  14.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8150201594180659, learning_rate=0.028265287079363134, max_depth=9, min_child_weight=1, n_estimators=50, reg_alpha=0.1342579998757471, reg_lambda=0.0001, subsample=0.8307783431647615; total time=   1.0s
# [CV] END colsample_bytree=0.8150201594180659, learning_rate=0.028265287079363134, max_depth=9, min_child_weight=1, n_estimators=50, reg_alpha=0.1342579998757471, reg_lambda=0.0001, subsample=0.8307783431647615; total time=   1.1s
# [CV] END colsample_bytree=0.8150201594180659, learning_rate=0.028265287079363134, max_depth=9, min_child_weight=1, n_estimators=50, reg_alpha=0.1342579998757471, reg_lambda=0.0001, subsample=0.8307783431647615; total time=   1.1s
# [CV] END colsample_bytree=0.8150201594180659, learning_rate=0.028265287079363134, max_depth=9, min_child_weight=1, n_estimators=50, reg_alpha=0.1342579998757471, reg_lambda=0.0001, subsample=0.8307783431647615; total time=   1.1s
# [CV] END colsample_bytree=0.8150201594180659, learning_rate=0.028265287079363134, max_depth=9, min_child_weight=1, n_estimators=50, reg_alpha=0.1342579998757471, reg_lambda=0.0001, subsample=0.8307783431647615; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7585220780634424, learning_rate=0.011627651781762689, max_depth=9, min_child_weight=4, n_estimators=50, reg_alpha=0.009479338845921214, reg_lambda=0.0001, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.7585220780634424, learning_rate=0.011627651781762689, max_depth=9, min_child_weight=4, n_estimators=50, reg_alpha=0.009479338845921214, reg_lambda=0.0001, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.7585220780634424, learning_rate=0.011627651781762689, max_depth=9, min_child_weight=4, n_estimators=50, reg_alpha=0.009479338845921214, reg_lambda=0.0001, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.7585220780634424, learning_rate=0.011627651781762689, max_depth=9, min_child_weight=4, n_estimators=50, reg_alpha=0.009479338845921214, reg_lambda=0.0001, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.7585220780634424, learning_rate=0.011627651781762689, max_depth=9, min_child_weight=4, n_estimators=50, reg_alpha=0.009479338845921214, reg_lambda=0.0001, subsample=1.0; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9281719609473047, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.007213664086137166, reg_lambda=0.0001, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.9281719609473047, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.007213664086137166, reg_lambda=0.0001, subsample=1.0; total time=  10.9s
# [CV] END colsample_bytree=0.9281719609473047, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.007213664086137166, reg_lambda=0.0001, subsample=1.0; total time=  11.3s
# [CV] END colsample_bytree=0.9281719609473047, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.007213664086137166, reg_lambda=0.0001, subsample=1.0; total time=  11.7s
# [CV] END colsample_bytree=0.9281719609473047, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.007213664086137166, reg_lambda=0.0001, subsample=1.0; total time=  12.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9483173080227627, learning_rate=0.013417317925849586, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.7344419650413461, reg_lambda=2.0, subsample=0.8904811551081684; total time=  20.7s
# [CV] END colsample_bytree=0.9483173080227627, learning_rate=0.013417317925849586, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.7344419650413461, reg_lambda=2.0, subsample=0.8904811551081684; total time=  20.8s
# [CV] END colsample_bytree=0.9483173080227627, learning_rate=0.013417317925849586, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.7344419650413461, reg_lambda=2.0, subsample=0.8904811551081684; total time=  21.0s
# [CV] END colsample_bytree=0.9483173080227627, learning_rate=0.013417317925849586, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.7344419650413461, reg_lambda=2.0, subsample=0.8904811551081684; total time=  21.0s
# [CV] END colsample_bytree=0.9483173080227627, learning_rate=0.013417317925849586, max_depth=9, min_child_weight=3, n_estimators=2000, reg_alpha=0.7344419650413461, reg_lambda=2.0, subsample=0.8904811551081684; total time=  21.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8354720212782338, learning_rate=0.016988937755638818, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.08430984461758138, reg_lambda=2.0, subsample=0.9167449779875692; total time=  17.9s
# [CV] END colsample_bytree=0.8354720212782338, learning_rate=0.016988937755638818, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.08430984461758138, reg_lambda=2.0, subsample=0.9167449779875692; total time=  18.1s
# [CV] END colsample_bytree=0.8354720212782338, learning_rate=0.016988937755638818, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.08430984461758138, reg_lambda=2.0, subsample=0.9167449779875692; total time=  18.4s
# [CV] END colsample_bytree=0.8354720212782338, learning_rate=0.016988937755638818, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.08430984461758138, reg_lambda=2.0, subsample=0.9167449779875692; total time=  18.4s
# [CV] END colsample_bytree=0.8354720212782338, learning_rate=0.016988937755638818, max_depth=9, min_child_weight=2, n_estimators=2000, reg_alpha=0.08430984461758138, reg_lambda=2.0, subsample=0.9167449779875692; total time=  18.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8670392738885293, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1138, reg_alpha=0.5454312853828786, reg_lambda=2.0, subsample=1.0; total time=   7.9s
# [CV] END colsample_bytree=0.8670392738885293, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1138, reg_alpha=0.5454312853828786, reg_lambda=2.0, subsample=1.0; total time=   8.1s
# [CV] END colsample_bytree=0.8670392738885293, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1138, reg_alpha=0.5454312853828786, reg_lambda=2.0, subsample=1.0; total time=   8.1s
# [CV] END colsample_bytree=0.8670392738885293, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1138, reg_alpha=0.5454312853828786, reg_lambda=2.0, subsample=1.0; total time=   8.3s
# [CV] END colsample_bytree=0.8670392738885293, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1138, reg_alpha=0.5454312853828786, reg_lambda=2.0, subsample=1.0; total time=   8.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9399123633467339, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.04936555081517329, reg_lambda=2.0, subsample=1.0; total time=   4.5s
# [CV] END colsample_bytree=0.9399123633467339, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.04936555081517329, reg_lambda=2.0, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.9399123633467339, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.04936555081517329, reg_lambda=2.0, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.9399123633467339, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.04936555081517329, reg_lambda=2.0, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=0.9399123633467339, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.04936555081517329, reg_lambda=2.0, subsample=1.0; total time=   4.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7304348522803635, learning_rate=0.013950879450281516, max_depth=3, min_child_weight=7, n_estimators=2000, reg_alpha=0.14549971661059125, reg_lambda=0.08022412654474731, subsample=0.7046787197509133; total time=   4.2s
# [CV] END colsample_bytree=0.7304348522803635, learning_rate=0.013950879450281516, max_depth=3, min_child_weight=7, n_estimators=2000, reg_alpha=0.14549971661059125, reg_lambda=0.08022412654474731, subsample=0.7046787197509133; total time=   4.2s
# [CV] END colsample_bytree=0.7304348522803635, learning_rate=0.013950879450281516, max_depth=3, min_child_weight=7, n_estimators=2000, reg_alpha=0.14549971661059125, reg_lambda=0.08022412654474731, subsample=0.7046787197509133; total time=   4.2s
# [CV] END colsample_bytree=0.7304348522803635, learning_rate=0.013950879450281516, max_depth=3, min_child_weight=7, n_estimators=2000, reg_alpha=0.14549971661059125, reg_lambda=0.08022412654474731, subsample=0.7046787197509133; total time=   4.2s
# [CV] END colsample_bytree=0.7304348522803635, learning_rate=0.013950879450281516, max_depth=3, min_child_weight=7, n_estimators=2000, reg_alpha=0.14549971661059125, reg_lambda=0.08022412654474731, subsample=0.7046787197509133; total time=   4.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9414864022172358, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1014, reg_alpha=0.0011268131797948357, reg_lambda=0.0001, subsample=0.8301556894322879; total time=   4.5s
# [CV] END colsample_bytree=0.9414864022172358, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1014, reg_alpha=0.0011268131797948357, reg_lambda=0.0001, subsample=0.8301556894322879; total time=   5.3s
# [CV] END colsample_bytree=0.9414864022172358, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1014, reg_alpha=0.0011268131797948357, reg_lambda=0.0001, subsample=0.8301556894322879; total time=   5.5s
# [CV] END colsample_bytree=0.9414864022172358, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1014, reg_alpha=0.0011268131797948357, reg_lambda=0.0001, subsample=0.8301556894322879; total time=   5.8s
# [CV] END colsample_bytree=0.9414864022172358, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=1014, reg_alpha=0.0011268131797948357, reg_lambda=0.0001, subsample=0.8301556894322879; total time=   6.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.053194100375583996, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.0011284602391434591, reg_lambda=2.0, subsample=1.0; total time=  16.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.053194100375583996, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.0011284602391434591, reg_lambda=2.0, subsample=1.0; total time=  16.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.053194100375583996, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.0011284602391434591, reg_lambda=2.0, subsample=1.0; total time=  17.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.053194100375583996, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.0011284602391434591, reg_lambda=2.0, subsample=1.0; total time=  17.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.053194100375583996, max_depth=9, min_child_weight=1, n_estimators=2000, reg_alpha=0.0011284602391434591, reg_lambda=2.0, subsample=1.0; total time=  17.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8471132690195473, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=1286, reg_alpha=0.4797190248415699, reg_lambda=0.016870924649802378, subsample=1.0; total time=  13.1s
# [CV] END colsample_bytree=0.8471132690195473, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=1286, reg_alpha=0.4797190248415699, reg_lambda=0.016870924649802378, subsample=1.0; total time=  13.1s
# [CV] END colsample_bytree=0.8471132690195473, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=1286, reg_alpha=0.4797190248415699, reg_lambda=0.016870924649802378, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=0.8471132690195473, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=1286, reg_alpha=0.4797190248415699, reg_lambda=0.016870924649802378, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=0.8471132690195473, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=1286, reg_alpha=0.4797190248415699, reg_lambda=0.016870924649802378, subsample=1.0; total time=  13.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.029771422802719105, max_depth=9, min_child_weight=5, n_estimators=2000, reg_alpha=0.23715318772433291, reg_lambda=2.0, subsample=1.0; total time=  13.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.029771422802719105, max_depth=9, min_child_weight=5, n_estimators=2000, reg_alpha=0.23715318772433291, reg_lambda=2.0, subsample=1.0; total time=  13.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.029771422802719105, max_depth=9, min_child_weight=5, n_estimators=2000, reg_alpha=0.23715318772433291, reg_lambda=2.0, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.029771422802719105, max_depth=9, min_child_weight=5, n_estimators=2000, reg_alpha=0.23715318772433291, reg_lambda=2.0, subsample=1.0; total time=  14.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.029771422802719105, max_depth=9, min_child_weight=5, n_estimators=2000, reg_alpha=0.23715318772433291, reg_lambda=2.0, subsample=1.0; total time=  14.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.07678140127902129, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.0001, reg_lambda=0.00852864397217226, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.07678140127902129, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.0001, reg_lambda=0.00852864397217226, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.07678140127902129, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.0001, reg_lambda=0.00852864397217226, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.07678140127902129, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.0001, reg_lambda=0.00852864397217226, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.07678140127902129, max_depth=3, min_child_weight=1, n_estimators=50, reg_alpha=0.0001, reg_lambda=0.00852864397217226, subsample=1.0; total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.012225977459452373, max_depth=9, min_child_weight=1, n_estimators=1090, reg_alpha=0.24668862283247617, reg_lambda=2.0, subsample=0.8554244271347893; total time=  20.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.012225977459452373, max_depth=9, min_child_weight=1, n_estimators=1090, reg_alpha=0.24668862283247617, reg_lambda=2.0, subsample=0.8554244271347893; total time=  20.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.012225977459452373, max_depth=9, min_child_weight=1, n_estimators=1090, reg_alpha=0.24668862283247617, reg_lambda=2.0, subsample=0.8554244271347893; total time=  21.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.012225977459452373, max_depth=9, min_child_weight=1, n_estimators=1090, reg_alpha=0.24668862283247617, reg_lambda=2.0, subsample=0.8554244271347893; total time=  21.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.012225977459452373, max_depth=9, min_child_weight=1, n_estimators=1090, reg_alpha=0.24668862283247617, reg_lambda=2.0, subsample=0.8554244271347893; total time=  21.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=1.0; total time=  13.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=1.0; total time=  13.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=1.0; total time=  13.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=1.0; total time=  13.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7816144512469954, learning_rate=0.021210312339182063, max_depth=4, min_child_weight=3, n_estimators=1000, reg_alpha=10.797036157803118, reg_lambda=0.06369563289678955, subsample=0.7914801194687562; total time=   3.1s
# [CV] END colsample_bytree=0.7816144512469954, learning_rate=0.021210312339182063, max_depth=4, min_child_weight=3, n_estimators=1000, reg_alpha=10.797036157803118, reg_lambda=0.06369563289678955, subsample=0.7914801194687562; total time=   3.1s
# [CV] END colsample_bytree=0.7816144512469954, learning_rate=0.021210312339182063, max_depth=4, min_child_weight=3, n_estimators=1000, reg_alpha=10.797036157803118, reg_lambda=0.06369563289678955, subsample=0.7914801194687562; total time=   3.1s
# [CV] END colsample_bytree=0.7816144512469954, learning_rate=0.021210312339182063, max_depth=4, min_child_weight=3, n_estimators=1000, reg_alpha=10.797036157803118, reg_lambda=0.06369563289678955, subsample=0.7914801194687562; total time=   3.2s
# [CV] END colsample_bytree=0.7816144512469954, learning_rate=0.021210312339182063, max_depth=4, min_child_weight=3, n_estimators=1000, reg_alpha=10.797036157803118, reg_lambda=0.06369563289678955, subsample=0.7914801194687562; total time=   3.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8110303729594301, learning_rate=0.012374810409031375, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0023951864292837363, reg_lambda=0.0018976303482581957, subsample=0.9042896887650804; total time=  10.7s
# [CV] END colsample_bytree=0.8110303729594301, learning_rate=0.012374810409031375, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0023951864292837363, reg_lambda=0.0018976303482581957, subsample=0.9042896887650804; total time=  10.8s
# [CV] END colsample_bytree=0.8110303729594301, learning_rate=0.012374810409031375, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0023951864292837363, reg_lambda=0.0018976303482581957, subsample=0.9042896887650804; total time=  10.8s
# [CV] END colsample_bytree=0.8110303729594301, learning_rate=0.012374810409031375, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0023951864292837363, reg_lambda=0.0018976303482581957, subsample=0.9042896887650804; total time=  10.9s
# [CV] END colsample_bytree=0.8110303729594301, learning_rate=0.012374810409031375, max_depth=9, min_child_weight=10, n_estimators=2000, reg_alpha=0.0023951864292837363, reg_lambda=0.0018976303482581957, subsample=0.9042896887650804; total time=  10.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7611667081780946, learning_rate=0.15489098264646656, max_depth=9, min_child_weight=1, n_estimators=654, reg_alpha=0.6229218163569822, reg_lambda=1.7578248138696477, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.7611667081780946, learning_rate=0.15489098264646656, max_depth=9, min_child_weight=1, n_estimators=654, reg_alpha=0.6229218163569822, reg_lambda=1.7578248138696477, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.7611667081780946, learning_rate=0.15489098264646656, max_depth=9, min_child_weight=1, n_estimators=654, reg_alpha=0.6229218163569822, reg_lambda=1.7578248138696477, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.7611667081780946, learning_rate=0.15489098264646656, max_depth=9, min_child_weight=1, n_estimators=654, reg_alpha=0.6229218163569822, reg_lambda=1.7578248138696477, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.7611667081780946, learning_rate=0.15489098264646656, max_depth=9, min_child_weight=1, n_estimators=654, reg_alpha=0.6229218163569822, reg_lambda=1.7578248138696477, subsample=1.0; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.16537036570065314, max_depth=9, min_child_weight=1, n_estimators=642, reg_alpha=0.10777687088839104, reg_lambda=0.0010847884109959484, subsample=0.7; total time=   3.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.16537036570065314, max_depth=9, min_child_weight=1, n_estimators=642, reg_alpha=0.10777687088839104, reg_lambda=0.0010847884109959484, subsample=0.7; total time=   3.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.16537036570065314, max_depth=9, min_child_weight=1, n_estimators=642, reg_alpha=0.10777687088839104, reg_lambda=0.0010847884109959484, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.16537036570065314, max_depth=9, min_child_weight=1, n_estimators=642, reg_alpha=0.10777687088839104, reg_lambda=0.0010847884109959484, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.16537036570065314, max_depth=9, min_child_weight=1, n_estimators=642, reg_alpha=0.10777687088839104, reg_lambda=0.0010847884109959484, subsample=0.7; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1664, reg_alpha=0.22533749103954323, reg_lambda=0.14159170612469588, subsample=0.8302683404150577; total time=  20.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1664, reg_alpha=0.22533749103954323, reg_lambda=0.14159170612469588, subsample=0.8302683404150577; total time=  20.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1664, reg_alpha=0.22533749103954323, reg_lambda=0.14159170612469588, subsample=0.8302683404150577; total time=  20.7s
# ...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1510, reg_alpha=0.004106299270611142, reg_lambda=2.0, subsample=1.0; total time=   9.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1510, reg_alpha=0.004106299270611142, reg_lambda=2.0, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1510, reg_alpha=0.004106299270611142, reg_lambda=2.0, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1510, reg_alpha=0.004106299270611142, reg_lambda=2.0, subsample=1.0; total time=  10.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=1510, reg_alpha=0.004106299270611142, reg_lambda=2.0, subsample=1.0; total time=  10.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.766109342794535, learning_rate=0.016960854949550148, max_depth=9, min_child_weight=10, n_estimators=1967, reg_alpha=0.5441655889426071, reg_lambda=0.0025700498159330902, subsample=0.8352778148186383; total time=   9.6s
# [CV] END colsample_bytree=0.766109342794535, learning_rate=0.016960854949550148, max_depth=9, min_child_weight=10, n_estimators=1967, reg_alpha=0.5441655889426071, reg_lambda=0.0025700498159330902, subsample=0.8352778148186383; total time=   9.8s
# [CV] END colsample_bytree=0.766109342794535, learning_rate=0.016960854949550148, max_depth=9, min_child_weight=10, n_estimators=1967, reg_alpha=0.5441655889426071, reg_lambda=0.0025700498159330902, subsample=0.8352778148186383; total time=   9.8s
# [CV] END colsample_bytree=0.766109342794535, learning_rate=0.016960854949550148, max_depth=9, min_child_weight=10, n_estimators=1967, reg_alpha=0.5441655889426071, reg_lambda=0.0025700498159330902, subsample=0.8352778148186383; total time=   9.8s
# [CV] END colsample_bytree=0.766109342794535, learning_rate=0.016960854949550148, max_depth=9, min_child_weight=10, n_estimators=1967, reg_alpha=0.5441655889426071, reg_lambda=0.0025700498159330902, subsample=0.8352778148186383; total time=   9.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=770, reg_alpha=0.5430010010125477, reg_lambda=0.0001, subsample=1.0; total time=  21.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=770, reg_alpha=0.5430010010125477, reg_lambda=0.0001, subsample=1.0; total time=  21.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=770, reg_alpha=0.5430010010125477, reg_lambda=0.0001, subsample=1.0; total time=  21.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=770, reg_alpha=0.5430010010125477, reg_lambda=0.0001, subsample=1.0; total time=  21.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=770, reg_alpha=0.5430010010125477, reg_lambda=0.0001, subsample=1.0; total time=  21.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7587633308713913, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=1.0840814522474533, reg_lambda=2.0, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7587633308713913, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=1.0840814522474533, reg_lambda=2.0, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7587633308713913, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=1.0840814522474533, reg_lambda=2.0, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.7587633308713913, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=1.0840814522474533, reg_lambda=2.0, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.7587633308713913, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=2000, reg_alpha=1.0840814522474533, reg_lambda=2.0, subsample=1.0; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1227, reg_alpha=0.00919652007766709, reg_lambda=2.0, subsample=1.0; total time=  20.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1227, reg_alpha=0.00919652007766709, reg_lambda=2.0, subsample=1.0; total time=  20.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1227, reg_alpha=0.00919652007766709, reg_lambda=2.0, subsample=1.0; total time=  20.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1227, reg_alpha=0.00919652007766709, reg_lambda=2.0, subsample=1.0; total time=  20.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=1227, reg_alpha=0.00919652007766709, reg_lambda=2.0, subsample=1.0; total time=  20.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9679256695682827, learning_rate=0.043498316435837306, max_depth=6, min_child_weight=1, n_estimators=813, reg_alpha=0.003942188517161445, reg_lambda=2.0, subsample=1.0; total time=   7.3s
# [CV] END colsample_bytree=0.9679256695682827, learning_rate=0.043498316435837306, max_depth=6, min_child_weight=1, n_estimators=813, reg_alpha=0.003942188517161445, reg_lambda=2.0, subsample=1.0; total time=   7.3s
# [CV] END colsample_bytree=0.9679256695682827, learning_rate=0.043498316435837306, max_depth=6, min_child_weight=1, n_estimators=813, reg_alpha=0.003942188517161445, reg_lambda=2.0, subsample=1.0; total time=   7.3s
# [CV] END colsample_bytree=0.9679256695682827, learning_rate=0.043498316435837306, max_depth=6, min_child_weight=1, n_estimators=813, reg_alpha=0.003942188517161445, reg_lambda=2.0, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.9679256695682827, learning_rate=0.043498316435837306, max_depth=6, min_child_weight=1, n_estimators=813, reg_alpha=0.003942188517161445, reg_lambda=2.0, subsample=1.0; total time=   7.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=1275, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=1275, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=1275, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=1275, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=1275, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   5.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   5.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=2.0, subsample=1.0; total time=   5.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.7; total time=   5.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.7; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.7; total time=   5.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.7; total time=   5.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=2000, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.7; total time=   5.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7530281280534021, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=983, reg_alpha=0.012734483204724064, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.7530281280534021, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=983, reg_alpha=0.012734483204724064, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.7530281280534021, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=983, reg_alpha=0.012734483204724064, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.7530281280534021, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=983, reg_alpha=0.012734483204724064, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.7530281280534021, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=983, reg_alpha=0.012734483204724064, reg_lambda=2.0, subsample=1.0; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=565, reg_alpha=0.0001, reg_lambda=0.7756319003436659, subsample=0.9531572202287557; total time=   3.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=565, reg_alpha=0.0001, reg_lambda=0.7756319003436659, subsample=0.9531572202287557; total time=   4.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=565, reg_alpha=0.0001, reg_lambda=0.7756319003436659, subsample=0.9531572202287557; total time=   4.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=565, reg_alpha=0.0001, reg_lambda=0.7756319003436659, subsample=0.9531572202287557; total time=   4.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=565, reg_alpha=0.0001, reg_lambda=0.7756319003436659, subsample=0.9531572202287557; total time=   4.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7087683987199739, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=965, reg_alpha=0.5337433788913833, reg_lambda=2.0, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.7087683987199739, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=965, reg_alpha=0.5337433788913833, reg_lambda=2.0, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.7087683987199739, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=965, reg_alpha=0.5337433788913833, reg_lambda=2.0, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.7087683987199739, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=965, reg_alpha=0.5337433788913833, reg_lambda=2.0, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.7087683987199739, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=965, reg_alpha=0.5337433788913833, reg_lambda=2.0, subsample=1.0; total time=   2.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, min_child_weight=10, n_estimators=2000, reg_alpha=1.635919423661036, reg_lambda=2.0, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, min_child_weight=10, n_estimators=2000, reg_alpha=1.635919423661036, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, min_child_weight=10, n_estimators=2000, reg_alpha=1.635919423661036, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, min_child_weight=10, n_estimators=2000, reg_alpha=1.635919423661036, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, min_child_weight=10, n_estimators=2000, reg_alpha=1.635919423661036, reg_lambda=2.0, subsample=1.0; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=412, reg_alpha=0.0007330825918547376, reg_lambda=2.0, subsample=0.9595583979856632; total time=   2.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=412, reg_alpha=0.0007330825918547376, reg_lambda=2.0, subsample=0.9595583979856632; total time=   3.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=412, reg_alpha=0.0007330825918547376, reg_lambda=2.0, subsample=0.9595583979856632; total time=   3.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=412, reg_alpha=0.0007330825918547376, reg_lambda=2.0, subsample=0.9595583979856632; total time=   3.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=9, min_child_weight=1, n_estimators=412, reg_alpha=0.0007330825918547376, reg_lambda=2.0, subsample=0.9595583979856632; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7960556043099122, learning_rate=0.18800414372390076, max_depth=3, min_child_weight=1, n_estimators=718, reg_alpha=0.03081111574718089, reg_lambda=0.2680222822749208, subsample=0.7624201390789856; total time=   1.8s
# [CV] END colsample_bytree=0.7960556043099122, learning_rate=0.18800414372390076, max_depth=3, min_child_weight=1, n_estimators=718, reg_alpha=0.03081111574718089, reg_lambda=0.2680222822749208, subsample=0.7624201390789856; total time=   1.8s
# [CV] END colsample_bytree=0.7960556043099122, learning_rate=0.18800414372390076, max_depth=3, min_child_weight=1, n_estimators=718, reg_alpha=0.03081111574718089, reg_lambda=0.2680222822749208, subsample=0.7624201390789856; total time=   1.8s
# [CV] END colsample_bytree=0.7960556043099122, learning_rate=0.18800414372390076, max_depth=3, min_child_weight=1, n_estimators=718, reg_alpha=0.03081111574718089, reg_lambda=0.2680222822749208, subsample=0.7624201390789856; total time=   1.9s
# [CV] END colsample_bytree=0.7960556043099122, learning_rate=0.18800414372390076, max_depth=3, min_child_weight=1, n_estimators=718, reg_alpha=0.03081111574718089, reg_lambda=0.2680222822749208, subsample=0.7624201390789856; total time=   1.8s
# Best parameters:  OrderedDict({'colsample_bytree': 0.8354720212782338, 'learning_rate': 0.016988937755638818, 'max_depth': 9, 'min_child_weight': 2, 'n_estimators': 2000, 'reg_alpha': 0.08430984461758138, 'reg_lambda': 2.0, 'subsample': 0.9167449779875692})
# Best score (f1_weighted):  0.7912828904805138
#
# Total tuning time: 1109.27 seconds
