# %%
import BECancerResistome
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, average_precision_score, f1_score
from sklearn.preprocessing import label_binarize, StandardScaler
from sklearn.metrics import precision_recall_curve, average_precision_score
import time
import shap
import optuna
import umap

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load Data

# %%
annotated_control_df = pd.read_csv("data/8_Cellular_Drug_Context/zscores-unambiguous-VEPannotated-processed-protvar-cellular_drug_context-control.csv")

# %% [markdown]
# # Select dataset for prediction

# %%
annotated_variants_df = annotated_control_df

# %% [markdown]
# # Filter for EG

# %%
#Keep only EG samples
annotated_variants_df = annotated_variants_df[annotated_variants_df['Source'] == 'EG'].copy()

# %%
len(annotated_variants_df)
# Out:
# 84024

# %% [markdown]
# # Classification

# %% [markdown]
# ## Encode labels

# %%
#Define Sensitivity, Neutral and Resistance classes
annotated_variants_df['Class'] = annotated_variants_df['Hit_class'].replace({'negative': 'Sensitivity', 'non-hit': 'Neutral', 'positive': 'Resistance'})
annotated_variants_df.drop(columns=['Hit_class'], inplace=True)

#Encode Classes
le = LabelEncoder()
annotated_variants_df['Class_encoded'] = le.fit_transform(annotated_variants_df['Class'])

# %%
# Check encoding mapping
label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Label mapping:", label_mapping)
# Out:
# Label mapping: {'Neutral': np.int64(0), 'Resistance': np.int64(1), 'Sensitivity': np.int64(2)}

# %%
annotated_variants_df['Class_encoded'].value_counts()
# Out:
# Class_encoded
# 0    82785
# 1      788
# 2      451
# Name: count, dtype: int64

# %%
annotated_variants_df['Class'].value_counts()
# Out:
# Class
# Neutral        82785
# Resistance       788
# Sensitivity      451
# Name: count, dtype: int64

# %% [markdown]
# ## Define Train and Test sets

# %%
genes_to_hold_out = ['EGFR', 'FGFR2' 'GAB1', 'KRAS', 'NRAS', 'MAP2K1', 'MAP2K2', 'PIK3CA', 'PIK3CB', 'PIK3CD']

# %%
train_df = annotated_variants_df[~annotated_variants_df['Gene'].isin(genes_to_hold_out)].copy()
test_df = annotated_variants_df[annotated_variants_df['Gene'].isin(genes_to_hold_out)].copy()

# %%
len(train_df), len(test_df)
# Out:
# (65790, 18234)

# %%
train_df['Class'].value_counts()
# Out:
# Class
# Neutral        64750
# Resistance       675
# Sensitivity      365
# Name: count, dtype: int64

# %%
test_df['Class'].value_counts()
# Out:
# Class
# Neutral        18035
# Resistance       113
# Sensitivity       86
# Name: count, dtype: int64

# %% [markdown]
# ## Handle Class Imbalance

# %%
class_counts_train = train_df['Class'].value_counts()
class_proportions_train= train_df['Class'].value_counts(normalize=True)

print("Class counts:\n", class_counts_train)
print("\nClass percentage:\n", (class_proportions_train*100).round(2))
# Out:
# Class counts:
#  Class
# Neutral        64750
# Resistance       675
# Sensitivity      365
# Name: count, dtype: int64
#
# Class percentage:
#  Class
# Neutral        98.42
# Resistance      1.03
# Sensitivity     0.55
# Name: proportion, dtype: float64

# %%
class_counts_test = test_df['Class'].value_counts()
class_proportions_test = test_df['Class'].value_counts(normalize=True)
print("Class counts:\n", class_counts_test)
print("\nClass percentage:\n", (class_proportions_test*100).round(2))
# Out:
# Class counts:
#  Class
# Neutral        18035
# Resistance       113
# Sensitivity       86
# Name: count, dtype: int64
#
# Class percentage:
#  Class
# Neutral        98.91
# Resistance      0.62
# Sensitivity     0.47
# Name: proportion, dtype: float64

# %%
def stratified_downsampling(df, class_col, random_state=None):
    #Infer majority class + target size (length of the second largest class)
    class_counts = df[class_col].value_counts()
    majority_class = class_counts.idxmax()
    target_size = class_counts.nlargest(2).iloc[-1]

    #Separate majority class and other classes
    major_df = df[df[class_col] == majority_class]
    other_df = df[df[class_col] != majority_class]

    # If majority already not bigger than target, nothing to do
    if len(major_df) <= target_size:
        return df.copy()
    
    #Compute distribution of the majority df across Cell_Line and Gene
    major_distribution = (
        major_df
        .groupby(['Cell_Line', 'Gene'])
        .size()
        .reset_index(name='Count')
    )

    # Calculate proportions
    major_distribution['Proportion'] = major_distribution['Count'] / major_distribution['Count'].sum()

    # Determine number of samples to select from each Cell_Line × Gene group
    major_distribution['Target'] = np.floor(major_distribution['Proportion'] * target_size).astype(int)

    # Adjust target to ensure total matches target size 
    # i.e., distribute the remaining samples to the groups with the largest fractional remainders
    difference = target_size - major_distribution['Target'].sum()
    if difference > 0:
        fractional_parts = major_distribution['Proportion'] * target_size - major_distribution['Target']
        top_idx = fractional_parts.nlargest(difference).index
        major_distribution.loc[top_idx, 'Target'] += 1

    #Perform stratified downsampling
    downsampled_major_dfs= []
    for _, row in major_distribution.iterrows():
        cell_line = row['Cell_Line']
        gene = row['Gene']
        target = row['Target']

        subset = major_df[(major_df['Cell_Line'] == cell_line) & (major_df['Gene'] == gene)]

        if target > 0:
            n_sampled = min(target, len(subset)) # in case it is a very small group - but can lead to less samples than target_size overall
            downsampled_major_dfs.append(subset.sample(n=n_sampled, random_state=random_state))
    
    #Keep the indices until after the Top up step
    downsampled_majority_class_df = pd.concat(downsampled_major_dfs, axis=0)

    #Top up if needed (if very small groups caused total to be less than target_size)
    current_size = len(downsampled_majority_class_df)
    missing = target_size - current_size

    if missing>0: #ask supervisor if this is really needed
        remaining_samples = major_df.loc[~major_df.index.isin(downsampled_majority_class_df.index)]
        assert not remaining_samples.empty, ("Logic error: remaining_samples is empty but target_size not reached.")
        extra_n= min(missing, len(remaining_samples))
        extra_samples = remaining_samples.sample(n=extra_n, random_state=random_state)

        #Random subsample from the remaining samples now
        downsampled_majority_class_df = pd.concat([downsampled_majority_class_df, extra_samples], axis=0)

    # Reset index only at the end
    downsampled_majority_class_df = downsampled_majority_class_df.reset_index(drop=True)

    #Combine downsampled majority class with other classes
    balanced_df = pd.concat([downsampled_majority_class_df, other_df], ignore_index=True)

    return balanced_df

# %%
#Balanced dataset
train_df_balanced = stratified_downsampling(train_df, class_col='Class', random_state=1)
test_df_balanced = stratified_downsampling(test_df, class_col='Class', random_state=1)

# %% [markdown]
# ## Modeling

# %%
#Define meta data columns to drop
meta_cols=[
    'Guide', 'Editor', 'Gene', 'Cell_Line', 'Drug', 'zscore', 'Source', 'Target Transcript ID', 'uniprot_accession',
    'RefSeq match transcript (MANE Select)', 'Amino Acid Edits', 'aa_change', 'pocket_id', 'Class'
]

# %%
def train_test_once_no_cv(train_df, test_df, model, meta_cols, le, stratified_downsampling, class_col, random_state_for_downsampling):
    
    #Downsample training set
    train_df_balanced = stratified_downsampling(train_df, class_col = class_col, random_state=random_state_for_downsampling)
    test_df_balanced = stratified_downsampling(test_df, class_col = class_col, random_state=1)

    #Without downsampling for this version
    #train_df_balanced = train_df.copy()

    #Print class distribution after downsampling
    print("Class distribution after downsampling:")
    print(train_df_balanced['Class'].value_counts())

    #Print class distribution in test set after downsampling
    print("Test set class distribution after downsampling:")
    print(test_df_balanced['Class'].value_counts())

    #Split features and labels
    X_train = train_df_balanced.drop(columns="Class_encoded")
    y_train = train_df_balanced["Class_encoded"]

    X_test = test_df_balanced.drop(columns="Class_encoded")
    y_test = test_df_balanced["Class_encoded"]

    #Store meta data for test set
    meta_X_test = X_test[meta_cols].copy()
    meta_X_test['original_index'] = X_test.index

    X_train = X_train.drop(columns=meta_cols)
    X_test  = X_test.drop(columns=meta_cols)

    #Train model
    model.fit(X_train, y_train)

    #Predict on test set
    y_pred = model.predict(X_test)
    probs = model.predict_proba(X_test)

    #Metrics
    class_names = list(le.classes_)
    metrics = {}

    report = classification_report(y_test, y_pred, target_names=class_names, output_dict=True)

    metrics['accuracy'] = report['accuracy']

    for avg_key in ['macro avg', 'weighted avg']:
        metrics[f'precision_{avg_key}'] = report[avg_key]['precision']
        metrics[f'recall_{avg_key}'] = report[avg_key]['recall']
        metrics[f'f1_{avg_key}'] = report[avg_key]['f1-score']

    for cname in class_names:
        metrics[f'precision_{cname}'] = report[cname]['precision']
        metrics[f'recall_{cname}'] = report[cname]['recall']
        metrics[f'f1_{cname}'] = report[cname]['f1-score']

    
    metrics['roc_auc_weighted'] = roc_auc_score(y_test, probs, multi_class='ovr', average='weighted')
    metrics['roc_auc_macro'] = roc_auc_score(y_test, probs, multi_class='ovr', average='macro')

    metrics['pr_auc_weighted'] = average_precision_score(y_test, probs, average='weighted')
    metrics['pr_auc_macro'] = average_precision_score(y_test, probs, average='macro')

    #Confusion Matrix
    cm = confusion_matrix(y_test, y_pred, labels=np.arange(len(class_names)))

    return metrics, cm, y_test.values, y_pred, probs

# %% [markdown]
# ### Define Model and Cross-Validation

# %%
optimized_params = {'n_estimators': 473,
                    'max_depth': 8,
                    'learning_rate': 0.014757846958987166,
                    'subsample': 0.9074779169306355,
                    'colsample_bytree': 0.5480484893807359,
                    'min_child_weight': 1,
                    'reg_alpha': 0.0004937375718649116,
                    'reg_lambda': 0.000319094062330884,
                    'gamma': 0.6244886434704836}


#Define optimized XGBClassifier with Optuna parameters  
xgb_classifier_optimized = XGBClassifier(
    **optimized_params                   
)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# ### Run Model

# %%
# Run multiple times to get average performance across different downsamplings
n_runs=10

all_metrics, all_cms = [], []
all_y_true_runs, all_y_pred_runs, all_probs_runs = [], [], []

for i in range(n_runs):
    print(f"\n--- Run {i+1}/{n_runs} ---")

    metrics, cm, y_true, y_pred, probs = train_test_once_no_cv(
        train_df=train_df,
        test_df=test_df,
        model=xgb_classifier_optimized,
        meta_cols=meta_cols,
        le=le,
        stratified_downsampling=stratified_downsampling,
        class_col="Class",
        random_state_for_downsampling=i
    )

    all_metrics.append(metrics)
    all_cms.append(cm)
    all_y_true_runs.append(y_true)
    all_y_pred_runs.append(y_pred)
    all_probs_runs.append(probs)

    print("Metrics:", metrics)
    print("Confusion Matrix:\n", cm)

# === Aggregate metrics across runs ===
metrics_df = pd.DataFrame(all_metrics)
metrics_mean = metrics_df.mean()
metrics_std = metrics_df.std()

cm_mean = np.mean(np.array(all_cms, dtype=float), axis=0)
cm_std  = np.std(np.array(all_cms, dtype=float), axis=0)

desired_order = ["Sensitivity", "Neutral", "Resistance"]

# Map to label encoder indices
reorder_idx = [list(le.classes_).index(c) for c in desired_order]

# Reorder rows and columns
cm_mean = cm_mean[np.ix_(reorder_idx, reorder_idx)]
cm_std  = cm_std[np.ix_(reorder_idx, reorder_idx)]

# Update class_names for correct axis labels
class_names_reordered = desired_order

print("=== Mean metrics ===")
print(metrics_mean)
print("\n=== Std metrics ===")
print(metrics_std)

print("\n=== Mean confusion matrix ===")
print(cm_mean)
print("\n=== Std confusion matrix ===")
print(cm_std)
# Out:
# --- Run 1/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.40705128205128205, 'precision_macro avg': 0.36704603970280697, 'recall_macro avg': 0.3774096178911985, 'f1_macro avg': 0.31693157240902825, 'precision_weighted avg': 0.369963485446319, 'recall_weighted avg': 0.40705128205128205, 'f1_weighted avg': 0.3388927560537367, 'precision_Neutral': 0.4742268041237113, 'recall_Neutral': 0.8141592920353983, 'f1_Neutral': 0.5993485342019544, 'precision_Resistance': 0.29357798165137616, 'recall_Resistance': 0.2831858407079646, 'f1_Resistance': 0.2882882882882883, 'precision_Sensitivity': 0.3333333333333333, 'recall_Sensitivity': 0.03488372093023256, 'f1_Sensitivity': 0.06315789473684211, 'roc_auc_weighted': np.float64(0.5589263540301918), 'roc_auc_macro': np.float64(0.5454309001273087), 'pr_auc_weighted': np.float64(0.40688901904360475), 'pr_auc_macro': np.float64(0.3941275342982797)}
# Confusion Matrix:
#  [[92 18  3]
#  [78 32  3]
#  [24 59  3]]
#
# --- Run 2/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.4423076923076923, 'precision_macro avg': 0.28816158042164236, 'recall_macro avg': 0.4070796460176991, 'f1_macro avg': 0.3332574636774022, 'precision_weighted avg': 0.3130986402658229, 'recall_weighted avg': 0.4423076923076923, 'f1_weighted avg': 0.3620970518802543, 'precision_Neutral': 0.49473684210526314, 'recall_Neutral': 0.831858407079646, 'f1_Neutral': 0.6204620462046204, 'precision_Resistance': 0.3697478991596639, 'recall_Resistance': 0.3893805309734513, 'f1_Resistance': 0.3793103448275862, 'precision_Sensitivity': 0.0, 'recall_Sensitivity': 0.0, 'f1_Sensitivity': 0.0, 'roc_auc_weighted': np.float64(0.5698485478219325), 'roc_auc_macro': np.float64(0.557159209644987), 'pr_auc_weighted': np.float64(0.40881238356789884), 'pr_auc_macro': np.float64(0.3966177656211935)}
# Confusion Matrix:
#  [[94 17  2]
#  [68 44  1]
#  [28 58  0]]
#
# --- Run 3/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.4198717948717949, 'precision_macro avg': 0.36494155033480874, 'recall_macro avg': 0.389209027920697, 'f1_macro avg': 0.3357504805172113, 'precision_weighted avg': 0.3729216320508455, 'recall_weighted avg': 0.4198717948717949, 'f1_weighted avg': 0.3594529160338176, 'precision_Neutral': 0.4887640449438202, 'recall_Neutral': 0.7699115044247787, 'f1_Neutral': 0.5979381443298969, 'precision_Resistance': 0.3333333333333333, 'recall_Resistance': 0.36283185840707965, 'f1_Resistance': 0.3474576271186441, 'precision_Sensitivity': 0.2727272727272727, 'recall_Sensitivity': 0.03488372093023256, 'f1_Sensitivity': 0.061855670103092786, 'roc_auc_weighted': np.float64(0.5547732422037576), 'roc_auc_macro': np.float64(0.5420839189430035), 'pr_auc_weighted': np.float64(0.3953782369132041), 'pr_auc_macro': np.float64(0.38339063738840756)}
# Confusion Matrix:
#  [[87 23  3]
#  [67 41  5]
#  [24 59  3]]
#
# --- Run 4/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.3974358974358974, 'precision_macro avg': 0.24529922842507945, 'recall_macro avg': 0.36578171091445427, 'f1_macro avg': 0.2846886446886447, 'precision_weighted avg': 0.2665270462695574, 'recall_weighted avg': 0.3974358974358974, 'f1_weighted avg': 0.3093251620174697, 'precision_Neutral': 0.45754716981132076, 'recall_Neutral': 0.8584070796460177, 'f1_Neutral': 0.5969230769230769, 'precision_Resistance': 0.27835051546391754, 'recall_Resistance': 0.23893805309734514, 'f1_Resistance': 0.2571428571428571, 'precision_Sensitivity': 0.0, 'recall_Sensitivity': 0.0, 'f1_Sensitivity': 0.0, 'roc_auc_weighted': np.float64(0.5828151564493674), 'roc_auc_macro': np.float64(0.5721091048988511), 'pr_auc_weighted': np.float64(0.4221386102224138), 'pr_auc_macro': np.float64(0.40935999073141316)}
# Confusion Matrix:
#  [[97 15  1]
#  [84 27  2]
#  [31 55  0]]
#
# --- Run 5/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.41346153846153844, 'precision_macro avg': 0.2637735849056604, 'recall_macro avg': 0.3805309734513274, 'f1_macro avg': 0.30492946445504543, 'precision_weighted avg': 0.28660014513788096, 'recall_weighted avg': 0.41346153846153844, 'f1_weighted avg': 0.33131759118673204, 'precision_Neutral': 0.48, 'recall_Neutral': 0.8495575221238938, 'f1_Neutral': 0.6134185303514377, 'precision_Resistance': 0.3113207547169811, 'recall_Resistance': 0.2920353982300885, 'f1_Resistance': 0.3013698630136986, 'precision_Sensitivity': 0.0, 'recall_Sensitivity': 0.0, 'f1_Sensitivity': 0.0, 'roc_auc_weighted': np.float64(0.5688758348128207), 'roc_auc_macro': np.float64(0.5547682502517389), 'pr_auc_weighted': np.float64(0.41233332431832664), 'pr_auc_macro': np.float64(0.39820189272480583)}
# Confusion Matrix:
#  [[96 14  3]
#  [77 33  3]
#  [27 59  0]]
#
# --- Run 6/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.42948717948717946, 'precision_macro avg': 0.27985480943738655, 'recall_macro avg': 0.3952802359882006, 'f1_macro avg': 0.3232690081235197, 'precision_weighted avg': 0.30407301410023735, 'recall_weighted avg': 0.42948717948717946, 'f1_weighted avg': 0.3512442107495936, 'precision_Neutral': 0.49473684210526314, 'recall_Neutral': 0.831858407079646, 'f1_Neutral': 0.6204620462046204, 'precision_Resistance': 0.3448275862068966, 'recall_Resistance': 0.35398230088495575, 'f1_Resistance': 0.34934497816593885, 'precision_Sensitivity': 0.0, 'recall_Sensitivity': 0.0, 'f1_Sensitivity': 0.0, 'roc_auc_weighted': np.float64(0.5609384139896213), 'roc_auc_macro': np.float64(0.5463934717836972), 'pr_auc_weighted': np.float64(0.4084268793580399), 'pr_auc_macro': np.float64(0.3958433942784347)}
# Confusion Matrix:
#  [[94 16  3]
#  [70 40  3]
#  [26 60  0]]
#
# --- Run 7/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.41346153846153844, 'precision_macro avg': 0.26263197586727, 'recall_macro avg': 0.3805309734513274, 'f1_macro avg': 0.30327523295875797, 'precision_weighted avg': 0.28535974300962985, 'recall_weighted avg': 0.41346153846153844, 'f1_weighted avg': 0.3295202050417274, 'precision_Neutral': 0.47058823529411764, 'recall_Neutral': 0.8495575221238938, 'f1_Neutral': 0.6056782334384858, 'precision_Resistance': 0.3173076923076923, 'recall_Resistance': 0.2920353982300885, 'f1_Resistance': 0.30414746543778803, 'precision_Sensitivity': 0.0, 'recall_Sensitivity': 0.0, 'f1_Sensitivity': 0.0, 'roc_auc_weighted': np.float64(0.5719281681837826), 'roc_auc_macro': np.float64(0.5590690986661371), 'pr_auc_weighted': np.float64(0.4108494488551197), 'pr_auc_macro': np.float64(0.39769097791746716)}
# Confusion Matrix:
#  [[96 15  2]
#  [78 33  2]
#  [30 56  0]]
#
# --- Run 8/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.40384615384615385, 'precision_macro avg': 0.39523765784443654, 'recall_macro avg': 0.3744597653838239, 'f1_macro avg': 0.3150462218499211, 'precision_weighted avg': 0.39235300460844685, 'recall_weighted avg': 0.40384615384615385, 'f1_weighted avg': 0.33672671065144966, 'precision_Neutral': 0.47643979057591623, 'recall_Neutral': 0.8053097345132744, 'f1_Neutral': 0.5986842105263158, 'precision_Resistance': 0.2807017543859649, 'recall_Resistance': 0.2831858407079646, 'f1_Resistance': 0.28193832599118945, 'precision_Sensitivity': 0.42857142857142855, 'recall_Sensitivity': 0.03488372093023256, 'f1_Sensitivity': 0.06451612903225806, 'roc_auc_weighted': np.float64(0.5653758068764517), 'roc_auc_macro': np.float64(0.556874204320636), 'pr_auc_weighted': np.float64(0.40696112322207484), 'pr_auc_macro': np.float64(0.3968931895968549)}
# Confusion Matrix:
#  [[91 20  2]
#  [79 32  2]
#  [21 62  3]]
#
# --- Run 9/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.4198717948717949, 'precision_macro avg': 0.34827160493827164, 'recall_macro avg': 0.38735679495095016, 'f1_macro avg': 0.31444435342198923, 'precision_weighted avg': 0.3567758784425451, 'recall_weighted avg': 0.4198717948717949, 'f1_weighted avg': 0.3397328070835075, 'precision_Neutral': 0.48, 'recall_Neutral': 0.8495575221238938, 'f1_Neutral': 0.6134185303514377, 'precision_Resistance': 0.3148148148148148, 'recall_Resistance': 0.3008849557522124, 'f1_Resistance': 0.3076923076923077, 'precision_Sensitivity': 0.25, 'recall_Sensitivity': 0.011627906976744186, 'f1_Sensitivity': 0.022222222222222223, 'roc_auc_weighted': np.float64(0.557958487125895), 'roc_auc_macro': np.float64(0.5438229943709079), 'pr_auc_weighted': np.float64(0.41521433789778117), 'pr_auc_macro': np.float64(0.40178733644949927)}
# Confusion Matrix:
#  [[96 15  2]
#  [78 34  1]
#  [26 59  1]]
#
# --- Run 10/10 ---
# Class distribution after downsampling:
# Class
# Neutral        675
# Resistance     675
# Sensitivity    365
# Name: count, dtype: int64
# Test set class distribution after downsampling:
# Class
# Neutral        113
# Resistance     113
# Sensitivity     86
# Name: count, dtype: int64
# Metrics: {'accuracy': 0.40705128205128205, 'precision_macro avg': 0.2623522458628842, 'recall_macro avg': 0.3746312684365782, 'f1_macro avg': 0.30520107034729255, 'precision_weighted avg': 0.2850558056010184, 'recall_weighted avg': 0.40705128205128205, 'f1_weighted avg': 0.331612701435039, 'precision_Neutral': 0.4787234042553192, 'recall_Neutral': 0.7964601769911505, 'f1_Neutral': 0.5980066445182725, 'precision_Resistance': 0.30833333333333335, 'recall_Resistance': 0.3274336283185841, 'f1_Resistance': 0.31759656652360513, 'precision_Sensitivity': 0.0, 'recall_Sensitivity': 0.0, 'f1_Sensitivity': 0.0, 'roc_auc_weighted': np.float64(0.5701276977125246), 'roc_auc_macro': np.float64(0.5590511727189146), 'pr_auc_weighted': np.float64(0.41576260254631564), 'pr_auc_macro': np.float64(0.40301645589422486)}
# Confusion Matrix:
#  [[90 20  3]
#  [75 37  1]
#  [23 63  0]]
# === Mean metrics ===
# accuracy                  0.415385
# precision_macro avg       0.307757
# recall_macro avg          0.383227
# f1_macro avg              0.313679
# precision_weighted avg    0.323273
# recall_weighted avg       0.415385
# f1_weighted avg           0.338992
# precision_Neutral         0.479576
# recall_Neutral            0.825664
# f1_Neutral                0.606434
# precision_Resistance      0.315232
# recall_Resistance         0.312389
# f1_Resistance             0.313429
# precision_Sensitivity     0.128463
# recall_Sensitivity        0.011628
# f1_Sensitivity            0.021175
# roc_auc_weighted          0.566157
# roc_auc_macro             0.553676
# pr_auc_weighted           0.410277
# pr_auc_macro              0.397693
# dtype: float64
#
# === Std metrics ===
# accuracy                  0.013189
# precision_macro avg       0.054950
# recall_macro avg          0.011882
# f1_macro avg              0.015175
# precision_weighted avg    0.045307
# recall_weighted avg       0.013189
# f1_weighted avg           0.015604
# precision_Neutral         0.011302
# recall_Neutral            0.028615
# f1_Neutral                0.009636
# precision_Resistance      0.028410
# recall_Resistance         0.045326
# f1_Resistance             0.036304
# precision_Sensitivity     0.172123
# recall_Sensitivity        0.016444
# f1_Sensitivity            0.029791
# roc_auc_weighted          0.008330
# roc_auc_macro             0.009272
# pr_auc_weighted           0.007069
# pr_auc_macro              0.006700
# dtype: float64
#
# === Mean confusion matrix ===
# [[ 1.  26.  59. ]
#  [ 2.4 93.3 17.3]
#  [ 2.3 75.4 35.3]]
#
# === Std confusion matrix ===
# [[1.34164079 2.96647939 2.28035085]
#  [0.66332496 3.06757233 2.75862284]
#  [1.18743421 5.14198405 4.85901225]]

# %%
def summarize_results(metrics_list, cms, class_names):
    """
    Summarize metrics (global + class-wise) and confusion matrices across runs.

    Parameters
    ----------
    metrics_list : list of dict
        Each element is the metrics dict returned from train_test_once.
    cms : list of np.ndarray
        Confusion matrices (one per run).
    class_names : list
        Names of classes for the confusion matrix.
    """

    # === Metrics summary ===
    metrics_keys = metrics_list[0].keys()
    summary = {}
    for key in metrics_keys:
        values = np.array([m[key] for m in metrics_list])
        summary[key] = (np.mean(values), np.std(values))

    print("\n=== Metrics Summary (mean ± std) ===")

    # Global averages
    for k in ["accuracy", "roc_auc_weighted", "roc_auc_macro",
              "pr_auc_weighted", "pr_auc_macro"]:
        mean, std = summary[k]
        print(f"{k:20s}: {mean:.3f} ± {std:.3f}")

    # Macro/weighted averages
    for k in ["precision_macro avg", "recall_macro avg", "f1_macro avg",
              "precision_weighted avg", "recall_weighted avg", "f1_weighted avg"]:
        if k in summary:
            mean, std = summary[k]
            print(f"{k:20s}: {mean:.3f} ± {std:.3f}")

    # Class-wise metrics
    print("\n=== Class-wise Metrics (mean ± std) ===")
    for cname in class_names:
        for metric in ["precision", "recall", "f1"]:
            key = f"{metric}_{cname}"
            if key in summary:
                mean, std = summary[key]
                print(f"{cname:10s} {metric:10s}: {mean:.3f} ± {std:.3f}")

   # === Confusion Matrix summary ===
    cm_array = np.stack(cms)
    cm_mean = np.mean(cm_array, axis=0)
    cm_std = np.std(cm_array, axis=0)

    # === Reorder ===
    desired_order = ["Sensitivity", "Neutral", "Resistance"]
    reorder_idx = [list(class_names).index(c) for c in desired_order]

    cm_mean = cm_mean[np.ix_(reorder_idx, reorder_idx)]
    cm_std  = cm_std[np.ix_(reorder_idx, reorder_idx)]

    class_names = desired_order

    # Combined annotated version
    combined = np.empty(cm_mean.shape, dtype=object)
    for i in range(cm_mean.shape[0]):
        for j in range(cm_mean.shape[1]):
            mean_val = int(round(cm_mean[i, j]))   
            std_val = int(cm_std[i, j])       
            combined[i, j] = f"{mean_val}±{std_val}"


    plt.figure(figsize=(2.5, 2.5))
    sns.heatmap(cm_mean, annot=combined, fmt="", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names, annot_kws={"size": 7})
    #plt.title("Confusion Matrix (mean ± std)")
    plt.yticks(fontsize=8)
    plt.xticks(fontsize=8)
    plt.xlabel("Predicted Label", fontsize=9)
    plt.ylabel("True Label", fontsize=9)
    plt.show()

# === Bar plot: Precision & Recall per class (mean ± std) ===
    precision_means = [summary[f"precision_{c}"][0] for c in class_names]
    precision_stds  = [summary[f"precision_{c}"][1] for c in class_names]
    recall_means    = [summary[f"recall_{c}"][0] for c in class_names]
    recall_stds     = [summary[f"recall_{c}"][1] for c in class_names]

    x = np.arange(len(class_names))
    width = 0.35

    plt.figure(figsize=(6, 5))
    bars1 = plt.bar(x - width/2, precision_means, width,
                    yerr=precision_stds, capsize=3,
                    label="Precision", color="lightsteelblue")
    bars2 = plt.bar(x + width/2, recall_means, width,
                    yerr=recall_stds, capsize=3,
                    label="Recall", color="midnightblue")

    # Add numbers on top
    for bar in bars1:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2 + 0.105, height + 0.005,
                 f"{height:.2f}", ha='center', va='bottom', fontsize=8)
    for bar in bars2:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2 + 0.105, height + 0.005,
                 f"{height:.2f}", ha='center', va='bottom', fontsize=8)

    plt.xticks(x, class_names, fontsize=8)
    plt.ylabel("Score", fontsize=9)
    plt.ylim(0, 1.05)
    plt.legend(loc="upper right", fontsize=6)
    plt.show()

    return summary, cm_mean, cm_std

# %%
metrics_summary, cm_mean, cm_std = summarize_results(all_metrics, all_cms,
                                                     class_names=le.classes_)
# Out:
# === Metrics Summary (mean ± std) ===
# accuracy            : 0.415 ± 0.013
# roc_auc_weighted    : 0.566 ± 0.008
# roc_auc_macro       : 0.554 ± 0.009
# pr_auc_weighted     : 0.410 ± 0.007
# pr_auc_macro        : 0.398 ± 0.006
# precision_macro avg : 0.308 ± 0.052
# recall_macro avg    : 0.383 ± 0.011
# f1_macro avg        : 0.314 ± 0.014
# precision_weighted avg: 0.323 ± 0.043
# recall_weighted avg : 0.415 ± 0.013
# f1_weighted avg     : 0.339 ± 0.015
#
# === Class-wise Metrics (mean ± std) ===
# Neutral    precision : 0.480 ± 0.011
# Neutral    recall    : 0.826 ± 0.027
# Neutral    f1        : 0.606 ± 0.009
# Resistance precision : 0.315 ± 0.027
# Resistance recall    : 0.312 ± 0.043
# Resistance f1        : 0.313 ± 0.034
# Sensitivity precision : 0.128 ± 0.163
# Sensitivity recall    : 0.012 ± 0.016
# Sensitivity f1        : 0.021 ± 0.028

# %% [markdown]
# ### F1 Plot per class

# %%
# Define your desired class order (using the metric keys used to index all metrics )
class_order = ["Sensitivity", "Neutral", "Resistance",  'macro avg']

# Display labels for the x-axis
display_labels = ["Sensitivity", "Neutral", "Resistance",  "Macro\nF1"]

# Compute mean and std in that order
f1_means = [np.mean([m[f"f1_{c}"] for m in all_metrics]) for c in class_order]
f1_stds  = [np.std([m[f"f1_{c}"] for m in all_metrics]) for c in class_order]

# Define consistent colors for each class
colors_bar = ["tomato", "#b3b3b3", "olivedrab", 'teal']

x = np.arange(len(display_labels))
plt.figure(figsize=(2.6,2.5))

bars = plt.bar(x, f1_means, yerr=f1_stds, capsize=3, color=colors_bar, width = 0.6, error_kw=dict(ecolor='black', lw=1.2))

# Add value labels
for i, bar in enumerate(bars):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.07, f"{height:.2f}", ha='center', va='bottom', fontsize=7)

plt.xticks(x, display_labels, fontsize=8)
plt.ylabel("F1-score", fontsize=9)
plt.yticks(fontsize=7)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
#Save the dataset used for the F1 plot
f1_results_to_plot_df = pd.DataFrame({
    "Class": class_order,
    "F1_mean": f1_means,
    "F1_std": f1_stds
})

f1_results_to_plot_df.to_csv("/Users/carolinapinto/desktop/Tese/Plots/Benchmarking/f1_scores_across_10_runs_plot_benchmark2.1_train-ht29.csv", index=False)

# %% [markdown]
# ### PR Curve

# %%
classes_for_binarize = np.arange(len(le.classes_))
colors = ["#b3b3b3", "olivedrab", "tomato"]
recall_grid = np.linspace(0, 1, 200)

plt.figure(figsize=(3,2.5))

for i, class_name in enumerate(le.classes_):
    precisions_interp = []
    aucs = []
    for y_true, probs in zip(all_y_true_runs, all_probs_runs):
        y_true_bin = label_binarize(y_true, classes=classes_for_binarize)
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], probs[:, i])
        auc = average_precision_score(y_true_bin[:, i], probs[:, i])
        aucs.append(auc)
        precisions_interp.append(np.interp(recall_grid, recall[::-1], precision[::-1]))

    mean_precision = np.mean(precisions_interp, axis=0)
    std_precision  = np.std(precisions_interp, axis=0)
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)

    plt.plot(recall_grid, mean_precision, color=colors[i], lw=2, label=f"{class_name} (AUC = {mean_auc:.2f})")
    plt.fill_between(recall_grid, mean_precision - std_precision, mean_precision + std_precision,
                     color=colors[i], alpha=0.2)

# Macro-average
macro_precisions = []
macro_aucs = []
for y_true, probs in zip(all_y_true_runs, all_probs_runs):
    y_true_bin = label_binarize(y_true, classes=classes_for_binarize)
    precision, recall, _ = precision_recall_curve(y_true_bin.ravel(), probs.ravel())
    macro_precisions.append(np.interp(recall_grid, recall[::-1], precision[::-1]))
    macro_aucs.append(average_precision_score(y_true_bin, probs, average="macro"))


mean_macro = np.mean(macro_precisions, axis=0)
std_macro = np.std(macro_precisions, axis=0)
mean_auc_macro = np.mean(macro_aucs)
std_auc_macro = np.std(macro_aucs)


plt.plot(recall_grid, mean_macro, color='black', lw=2, linestyle='--', label=f"Macro-average (AUC = {mean_auc_macro:.2f})")
plt.fill_between(recall_grid, mean_macro - std_macro, mean_macro + std_macro, color='black', alpha=0.2)

plt.xlabel("Recall", fontsize=9)
plt.xticks(fontsize=7)
plt.ylabel("Precision", fontsize=9)
plt.yticks(fontsize=7)
plt.legend(fontsize=6, loc="upper left", frameon=False, bbox_to_anchor=(0.5, 1.12))
#plt.legend(fontsize=7, loc="lower left", frameon=False, bbox_to_anchor=(0.13, 0.08))
plt.grid(alpha=0.4)
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.tight_layout()
plt.show()
